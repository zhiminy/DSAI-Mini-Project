# %% [markdown]
# # Data acquisition and Basic Descriptions

# %%
# Importing Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import squarify    # pip install squarify (algorithm for treemap)
from sklearn.tree import export_graphviz
import graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

sb.set()

# %%
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading https://files.pythonhosted.org/packages/0b/2b/2e77c35326efec19819cd1d729540d4d235e6c2a3f37658288a363a67da5/squarify-0.4.3-py3-none-any.whl
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
#Import the dataset
url = 'https://raw.githubusercontent.com/zzzhimin/DSAI-Mini-Project/master/AviationData.csv'
baseData = pd.read_csv(url,encoding = "ISO-8859-1")

# %%
baseData.shape
# Out:
# (84262, 31)

# %%
baseData.dtypes
# Out:
# Event.Id                   object
# Investigation.Type         object
# Accident.Number            object
# Event.Date                 object
# Location                   object
# Country                    object
# Latitude                  float64
# Longitude                 float64
# Airport.Code               object
# Airport.Name               object
# Injury.Severity            object
# Aircraft.Damage            object
# Aircraft.Category          object
# Registration.Number        object
# Make                       object
# Model                      object
# Amateur.Built              object
# Number.of.Engines         float64
# Engine.Type                object
# FAR.Description            object
# Schedule                   object
# Purpose.of.Flight          object
# Air.Carrier                object
# Total.Fatal.Injuries      float64
# Total.Serious.Injuries    float64
# Total.Minor.Injuries      float64
# Total.Uninjured           float64
# Weather.Condition          object
# Broad.Phase.of.Flight      object
# Report.Status              object
# Publication.Date           object
# dtype: object

# %%
baseData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84262 entries, 0 to 84261
# Data columns (total 31 columns):
# Event.Id                  84262 non-null object
# Investigation.Type        84257 non-null object
# Accident.Number           84262 non-null object
# Event.Date                84262 non-null object
# Location                  84185 non-null object
# Country                   83755 non-null object
# Latitude                  30163 non-null float64
# Longitude                 30154 non-null float64
# Airport.Code              47723 non-null object
# Airport.Name              50439 non-null object
# Injury.Severity           84262 non-null object
# Aircraft.Damage           81553 non-null object
# Aircraft.Category         27508 non-null object
# Registration.Number       80412 non-null object
# Make                      84192 non-null object
# Model                     84163 non-null object
# Amateur.Built             83653 non-null object
# Number.of.Engines         79228 non-null float64
# Engine.Type               80006 non-null object
# FAR.Description           27206 non-null object
# Schedule                  11843 non-null object
# Purpose.of.Flight         79382 non-null object
# Air.Carrier               4169 non-null object
# Total.Fatal.Injuries      57059 non-null float64
# Total.Serious.Injuries    54384 non-null float64
# Total.Minor.Injuries      55592 non-null float64
# Total.Uninjured           69673 non-null float64
# Weather.Condition         81159 non-null object
# Broad.Phase.of.Flight     77654 non-null object
# Report.Status             84262 non-null object
# Publication.Date          69947 non-null object
# dtypes: float64(7), object(24)
# memory usage: 19.9+ MB

# %%
baseData.describe() #Description of numeric data
# Out:
#            Latitude     Longitude  Number.of.Engines  Total.Fatal.Injuries  \
# count  30163.000000  30154.000000       79228.000000          57059.000000
# mean      37.544907    -93.508337           1.146930              0.847614
# std       12.370282     39.454412           0.447004              6.292468
# min      -78.016945   -178.676111           0.000000              0.000000
# 25%       33.307778   -114.861042           1.000000              0.000000
# 50%       38.125278    -94.371667           1.000000              0.000000
# 75%       42.524723    -81.650278           1.000000              1.000000
# max       89.218056    179.618611           8.000000            349.000000
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count            54384.000000          55592.000000     69673.000000
# mean                 0.331715              0.518708         5.901325
# std                  1.375602              2.771339        29.534302
# min                  0.000000              0.000000         0.000000
# 25%                  0.000000              0.000000         0.000000
# 50%                  0.000000              0.000000         1.000000
# 75%                  0.000000              1.000000         2.000000
# max                111.000000            380.000000       699.000000

# %%
#description of non numeric data
for i in baseData:
    if baseData[i].dtypes != 'float64':
        print(baseData[i].describe(), '\n\n')
# Out:
# count              84262
# unique             83035
# top       20001214X45071
# freq                   3
# Name: Event.Id, dtype: object
#
#
# count        84257
# unique           2
# top       Accident
# freq         80814
# Name: Investigation.Type, dtype: object
#
#
# count          84262
# unique         84262
# top       GAA19CA484
# freq               1
# Name: Accident.Number, dtype: object
#
#
# count          84262
# unique         13718
# top       2000-07-08
# freq              25
# Name: Event.Date, dtype: object
#
#
# count             84185
# unique            26575
# top       ANCHORAGE, AK
# freq                372
# Name: Location, dtype: object
#
#
# count             83755
# unique              179
# top       United States
# freq              78849
# Name: Country, dtype: object
#
#
# count     47723
# unique    10019
# top        NONE
# freq       1473
# Name: Airport.Code, dtype: object
#
#
# count       50439
# unique      23863
# top       PRIVATE
# freq          217
# Name: Airport.Name, dtype: object
#
#
# count         84262
# unique          128
# top       Non-Fatal
# freq          63516
# Name: Injury.Severity, dtype: object
#
#
# count           81553
# unique              3
# top       Substantial
# freq            60839
# Name: Aircraft.Damage, dtype: object
#
#
# count        27508
# unique          13
# top       Airplane
# freq         23569
# Name: Aircraft.Category, dtype: object
#
#
# count     80412
# unique    72557
# top        NONE
# freq        368
# Name: Registration.Number, dtype: object
#
#
# count      84192
# unique      8022
# top       CESSNA
# freq       17782
# Name: Make, dtype: object
#
#
# count     84163
# unique    11938
# top         152
# freq       2332
# Name: Model, dtype: object
#
#
# count     83653
# unique        2
# top          No
# freq      75570
# Name: Amateur.Built, dtype: object
#
#
# count             80006
# unique               13
# top       Reciprocating
# freq              68026
# Name: Engine.Type, dtype: object
#
#
# count                         27206
# unique                           18
# top       Part 91: General Aviation
# freq                          21600
# Name: FAR.Description, dtype: object
#
#
# count     11843
# unique        3
# top         UNK
# freq       4099
# Name: Schedule, dtype: object
#
#
# count        79382
# unique          22
# top       Personal
# freq         47204
# Name: Purpose.of.Flight, dtype: object
#
#
# count                4169
# unique               3030
# top       UNITED AIRLINES
# freq                   49
# Name: Air.Carrier, dtype: object
#
#
# count     81159
# unique        3
# top         VMC
# freq      74257
# Name: Weather.Condition, dtype: object
#
#
# count       77654
# unique         12
# top       LANDING
# freq        20625
# Name: Broad.Phase.of.Flight, dtype: object
#
#
# count              84262
# unique                 4
# top       Probable Cause
# freq               77216
# Name: Report.Status, dtype: object
#
#
# count          69947
# unique          3956
# top       31/03/1993
# freq             452
# Name: Publication.Date, dtype: object

# %% [markdown]
# # Extraction and Data Cleanup

# %%
aviationData = pd.DataFrame(baseData[['Latitude', 'Longitude', 'Injury.Severity', 'Aircraft.Damage', 'Aircraft.Category', 'Number.of.Engines', 'Engine.Type', 'Purpose.of.Flight', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured', 'Weather.Condition', 'Broad.Phase.of.Flight', 'Amateur.Built', 'FAR.Description']])

# %%
for i in aviationData:
    if(aviationData[i].dtypes != 'float64' and aviationData[i].dtypes != 'int64'):
        aviationData[i] = aviationData[i].str.upper()

# %%
#Removing ameteur built planes
aviationData = aviationData[aviationData['Amateur.Built'] == 'NO']

# %%
aviationData = aviationData.drop(['Amateur.Built'], axis = 1)

# %%
#New column for total passengers
aviationData['Total.Passengers'] = 0

# %%
#Filling up NaN values with 0 for empty passenger counts
for i in aviationData:
    if(i == 'Number.of.Engines'):
        continue
        
    if(aviationData[i].dtypes == 'float64' and i != 'Latitude' and i != 'Longitude'):
        aviationData[i] = aviationData[i].fillna(0)

# %%
#Finding missing airplane data by using passenger count as an estimate
for index, row in aviationData.iterrows():
    totalPassengers = aviationData.at[index, 'Total.Fatal.Injuries'] + aviationData.at[index, 'Total.Serious.Injuries'] + aviationData.at[index, 'Total.Minor.Injuries'] + aviationData.at[index, 'Total.Uninjured']
    if(totalPassengers > 30):
        aviationData.at[index, 'Aircraft.Category'] = 'AIRPLANE'
    aviationData.at[index, 'Total.Passengers'] = totalPassengers

# %%
#Removing non-airplane data
aviationData = aviationData[aviationData['Aircraft.Category'] == 'AIRPLANE']

# %%
#Removing aircrafts that have a purpose irrelevant to the problem
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'FIREFIGHTING']
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'GLIDER TOW']
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'AIR DROP']
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'SKYDIVING']
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'INSTRUCTIONAL']
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'BANNER TOW']
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'AERIAL OBSERVATION']
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'AIR RACE/SHOW']
aviationData = aviationData[aviationData['Purpose.of.Flight'] != 'AERIAL APPLICATION']

# %%
for index, row in aviationData.iterrows():
    if(aviationData.at[index, 'Purpose.of.Flight'] == 'PUBLIC AIRCRAFT - STATE' or aviationData.at[index, 'Purpose.of.Flight'] == 'PUBLIC AIRCRAFT - FEDERAL' or aviationData.at[index, 'Purpose.of.Flight'] == 'PUBLIC AIRCRAFT - LOCAL'):
        aviationData.at[index, 'Purpose.of.Flight'] = 'PUBLIC AIRCRAFT'

# %%
#Dropping rows with incomplete flight state info
for index, row in aviationData.iterrows():
    if(aviationData.at[index, 'Broad.Phase.of.Flight'] == 'UNKNOWN'):
        aviationData = aviationData.drop(index)
    
aviationData = aviationData.dropna(axis=0, subset=['Broad.Phase.of.Flight'])

# %%
#Removing rows with incomplete location data
for index, row in aviationData.iterrows():
    if(pd.isnull(aviationData.at[index, 'Latitude'])):
        aviationData.at[index, 'Latitude'] = aviationData['Latitude'].mean()
        
    if(pd.isnull(aviationData.at[index, 'Longitude'])):
        aviationData.at[index, 'Longitude'] = aviationData['Longitude'].mean()

# %%
#Dropping rows with incomplete passenger data
for index, row in aviationData.iterrows():
    if(aviationData.at[index, 'Total.Passengers'] == 0):
        aviationData = aviationData.drop(index)

# %%
#Removing airplane data with incomplete passenger counts
aviationData = aviationData.drop(['Aircraft.Category'], axis = 1)

# %%
#Filling in missing engine type data
for index, row in aviationData.iterrows():
    if(pd.isnull(aviationData.at[index,'Engine.Type'])):
            aviationData.at[index, 'Engine.Type'] = 'UNKNOWN'

# %%
for index, row in aviationData.iterrows():
    if(row['Injury.Severity'] != 'NON-FATAL' and row['Injury.Severity'] != 'INCIDENT'):
        aviationData.at[index, 'Injury.Severity'] = 'FATAL'
        
for index, row in aviationData.iterrows():
    if(row['Number.of.Engines'] == 0):
        aviationData.at[index, 'Number.of.Engines'] = 4

# %%
for index, row in aviationData.iterrows():
    if(pd.isnull(aviationData.at[index,'Purpose.of.Flight'])):
        aviationData.at[index, 'Purpose.of.Flight'] = 'UNKNOWN'

# %%
#Filling in missing damage data
for index, row in aviationData.iterrows():
    if(pd.isnull(aviationData.at[index,'Aircraft.Damage'])):
        if(aviationData.at[index,'Broad.Phase.of.Flight'] == 'LANDING' or aviationData.at[index,'Broad.Phase.of.Flight'] == 'CRUISE' or aviationData.at[index,'Broad.Phase.of.Flight'] == 'MANEUVERING' or aviationData.at[index,'Broad.Phase.of.Flight'] == 'LANDING'):
            aviationData.at[index, 'Aircraft.Damage'] = 'DESTROYED'
        elif(aviationData.at[index,'Broad.Phase.of.Flight'] == 'GO-AROUND' or aviationData.at[index,'Broad.Phase.of.Flight'] == 'STANDING' or aviationData.at[index,'Broad.Phase.of.Flight'] == 'TAXI' or aviationData.at[index, 'Aircraft.Damage'] == 'CLIMB'):
            aviationData.at[index, 'Aircraft.Damage'] = 'MINOR'
        else:
            aviationData.at[index, 'Aircraft.Damage'] = 'SUBSTANTIAL'

# %%
aviationData = aviationData[aviationData['FAR.Description'].notna()]

# %%
for index, row in aviationData.iterrows():
    if(pd.isnull(row['Number.of.Engines'])):
        aviationData.at[index, 'Number.of.Engines'] = 4

# %%
#Removing flights that are irrelevant to the problem
aviationData = aviationData[aviationData['FAR.Description'] != 'ARMED FORCES']
aviationData = aviationData[aviationData['FAR.Description'] != 'PAR 91 SUBPART K: FRACTIONAL']
aviationData = aviationData[aviationData['FAR.Description'] != 'PART 137: AGRICULTURAL']
aviationData = aviationData[aviationData['FAR.Description'] != 'PART 125: 20+ PAX 6000+ LBS']

# %%
#Removing engine types that do not match transportation aircrafts
aviationData = aviationData[aviationData['Engine.Type'] != 'TURBO SHAFT']
aviationData = aviationData[aviationData['Engine.Type'] != 'ELECTRIC']
aviationData = aviationData[aviationData['Engine.Type'] != 'REC, TJ, TJ']

# %%
aviationData = aviationData[aviationData['Broad.Phase.of.Flight'] != 'OTHER']

# %%
aviationData = aviationData.drop(['FAR.Description'], axis = 1)

# %%
#Ensuring injury severity matches fatality data
for index, row in aviationData.iterrows():
    if(aviationData.at[index, 'Injury.Severity'] == 'FATAL'):
        if(aviationData.at[index, 'Total.Fatal.Injuries'] == 0):
            aviationData.drop(index)
    else:
        if(aviationData.at[index, 'Total.Fatal.Injuries'] > 0):
            aviationData.drop(index)

# %%
#Converting whole number data to integer
for i in aviationData:
    if(aviationData[i].dtypes == 'float64' and i != 'Latitude' and i != 'Longitude'):
        aviationData[i] = aviationData[i].astype('int64')

# %%
#Reinitializing the index values for the rows to make them ordered and sequential
aviationData.index = range(len(aviationData))

# %%
#Using the given data in the dataset to determine the approximate altitude of the airplane during the accident

import requests
import urllib

# USGS Elevation Point Query Service
url = r'https://nationalmap.gov/epqs/pqs.php?'

# create data frame
df = pd.DataFrame({
    'lat': aviationData['Latitude'][:1],
    'lon': aviationData['Longitude'][:1]
})

def elevation_function(df, lat_column, lon_column):
    """Query service using lat, lon. add the elevation values as a new column."""
    elevations = []
    for lat, lon in zip(df[lat_column], df[lon_column]):

        # define rest query params
        params = {
            'output': 'json',
            'x': lon,
            'y': lat,
            'units': 'Meters'
        }

        # format query string and return query value
        result = requests.get((url + urllib.parse.urlencode(params)))
        elevations.append(result.json()['USGS_Elevation_Point_Query_Service']['Elevation_Query']['Elevation'])

    df['elev_meters'] = elevations

elevation_function(df, 'lat', 'lon')
df.head()
# Out:
#          lat         lon  elev_meters
# 0  39.128611 -123.715833        40.24

# %%
aviationData = pd.read_csv('Intermediate.csv')

# %%
#Using the data in our dataset and added elevation data to predict aircraft altitude
for index, row in aviationData.iterrows():
    if(aviationData.at[index, 'Broad.Phase.of.Flight'] == 'CRUISE' or aviationData.at[index, 'Broad.Phase.of.Flight'] == 'MANEUVERING' or aviationData.at[index, 'Broad.Phase.of.Flight'] == 'GO-AROUND'):
        if(aviationData.at[index, 'Purpose.of.Flight'] == 'PERSONAL'):
            altitude = 12496.8 - aviationData.at[index, 'Altitude']
            if(altitude > 0):
                aviationData.at[index, 'Altitude'] = altitude
        else:
            altitude = 10972 - aviationData.at[index, 'Altitude']
            if(altitude > 0):
                aviationData.at[index, 'Altitude'] = altitude
    
    if(aviationData.at[index, 'Broad.Phase.of.Flight'] == 'APPROACH' or aviationData.at[index, 'Broad.Phase.of.Flight'] == 'DESCENT' or aviationData.at[index, 'Broad.Phase.of.Flight'] == 'CLIMB'):
        altitude = 700 - aviationData.at[index, 'Altitude']
        if(altitude > 0):
            aviationData.at[index, 'Altitude'] = altitude

# %%
aviationData
# Out:
#        Altitude   Latitude   Longitude Injury.Severity Aircraft.Damage  \
# 0         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 1         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 2         202.7  41.968611  -87.907778       NON-FATAL     SUBSTANTIAL
# 3         202.7  41.968611  -87.907778       NON-FATAL           MINOR
# 4         215.4  35.213611  -80.948889       NON-FATAL     SUBSTANTIAL
# 5         215.4  35.213611  -80.948889       NON-FATAL           MINOR
# 6         332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 7         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 8         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 9         332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 10          2.3  25.793333  -80.290555        INCIDENT           MINOR
# 11      10266.5  55.216389  160.109722        INCIDENT           MINOR
# 12        367.2  39.164723  -96.610412        INCIDENT           MINOR
# 13        124.0  47.449722 -122.311667       NON-FATAL     SUBSTANTIAL
# 14        367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 15        367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 16        367.2  39.164723  -96.610412       NON-FATAL           MINOR
# 17        519.5  41.983889  -87.663611        INCIDENT     SUBSTANTIAL
# 18        519.5  41.983889  -87.663611        INCIDENT     SUBSTANTIAL
# 19       1635.6  39.861667 -104.673056        INCIDENT           MINOR
# 20       1635.6  39.861667 -104.673056        INCIDENT           MINOR
# 21          3.1  37.618889 -122.374723       NON-FATAL           MINOR
# 22        697.8  37.613333 -122.363889           FATAL       DESTROYED
# 23        395.2  33.636666  -84.428056        INCIDENT     SUBSTANTIAL
# 24         18.3  38.900000  -77.033334       NON-FATAL     SUBSTANTIAL
# 25         18.3  38.900000  -77.033334       NON-FATAL           MINOR
# 26        304.8  33.636666  -84.428056       NON-FATAL     SUBSTANTIAL
# 27        304.8  33.636666  -84.428056       NON-FATAL           MINOR
# 28      10970.0  21.318611 -157.922500       NON-FATAL       DESTROYED
# 29          2.3  25.793333  -80.290555       NON-FATAL     SUBSTANTIAL
# ...         ...        ...         ...             ...             ...
# 12980     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12981     367.2  39.164723  -96.610412        INCIDENT           MINOR
# 12982     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12983     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12984     332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12985     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12986     332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12987     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12988     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12989     367.2  39.164723  -96.610412       NON-FATAL       DESTROYED
# 12990     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12991     332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12992     332.8  39.164723  -96.610412        INCIDENT           MINOR
# 12993     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12994   12129.6  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12995   12129.6  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12996     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12997     332.8  39.164723  -96.610412       NON-FATAL       DESTROYED
# 12998     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12999     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 13000     332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 13001     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 13002     332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 13003     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 13004   10604.8  39.164723  -96.610412        INCIDENT           MINOR
# 13005   10604.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 13006     332.8  39.164723  -96.610412        INCIDENT           MINOR
# 13007     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 13008     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 13009   12129.6  39.164723  -96.610412       NON-FATAL       DESTROYED
#
#        Number.of.Engines    Engine.Type Purpose.of.Flight  \
# 0                      3      TURBO FAN           UNKNOWN
# 1                      4      TURBO FAN           UNKNOWN
# 2                      2      TURBO FAN           UNKNOWN
# 3                      2      TURBO FAN           UNKNOWN
# 4                      2      TURBO FAN           UNKNOWN
# 5                      2      TURBO FAN           UNKNOWN
# 6                      4        UNKNOWN           UNKNOWN
# 7                      4      TURBO JET           UNKNOWN
# 8                      3      TURBO FAN           UNKNOWN
# 9                      4      TURBO FAN           UNKNOWN
# 10                     4      TURBO FAN           UNKNOWN
# 11                     4      TURBO FAN           UNKNOWN
# 12                     4        UNKNOWN           UNKNOWN
# 13                     2      TURBO FAN           UNKNOWN
# 14                     4      TURBO FAN           UNKNOWN
# 15                     2     TURBO PROP           UNKNOWN
# 16                     3      TURBO FAN           UNKNOWN
# 17                     2        UNKNOWN           UNKNOWN
# 18                     2        UNKNOWN           UNKNOWN
# 19                     2      TURBO FAN           UNKNOWN
# 20                     2      TURBO FAN           UNKNOWN
# 21                     2      TURBO FAN           UNKNOWN
# 22                     2      TURBO FAN           UNKNOWN
# 23                     3      TURBO FAN           UNKNOWN
# 24                     2      TURBO FAN           UNKNOWN
# 25                     2      TURBO FAN           UNKNOWN
# 26                     2      TURBO JET           UNKNOWN
# 27                     2      TURBO FAN           UNKNOWN
# 28                     2      TURBO FAN           UNKNOWN
# 29                     2      TURBO FAN           UNKNOWN
# ...                  ...            ...               ...
# 12980                  1  RECIPROCATING          PERSONAL
# 12981                  1  RECIPROCATING          PERSONAL
# 12982                  1  RECIPROCATING          PERSONAL
# 12983                  1  RECIPROCATING          PERSONAL
# 12984                  1  RECIPROCATING          PERSONAL
# 12985                  1  RECIPROCATING          BUSINESS
# 12986                  1  RECIPROCATING          BUSINESS
# 12987                  1  RECIPROCATING          PERSONAL
# 12988                  1  RECIPROCATING          PERSONAL
# 12989                  1  RECIPROCATING           UNKNOWN
# 12990                  1  RECIPROCATING          PERSONAL
# 12991                  1  RECIPROCATING          PERSONAL
# 12992                  2     TURBO PROP             FERRY
# 12993                  1  RECIPROCATING          BUSINESS
# 12994                  1  RECIPROCATING          PERSONAL
# 12995                  1  RECIPROCATING          PERSONAL
# 12996                  1  RECIPROCATING           UNKNOWN
# 12997                  1  RECIPROCATING          PERSONAL
# 12998                  1  RECIPROCATING          PERSONAL
# 12999                  2  RECIPROCATING          PERSONAL
# 13000                  1  RECIPROCATING           UNKNOWN
# 13001                  1  RECIPROCATING          BUSINESS
# 13002                  1  RECIPROCATING          PERSONAL
# 13003                  1  RECIPROCATING           UNKNOWN
# 13004                  1  RECIPROCATING          BUSINESS
# 13005                  1  RECIPROCATING             FERRY
# 13006                  1  RECIPROCATING          PERSONAL
# 13007                  1  RECIPROCATING             FERRY
# 13008                  1  RECIPROCATING          PERSONAL
# 13009                  1  RECIPROCATING          PERSONAL
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                         0                       0                     0
# 1                         0                       0                     0
# 2                         0                       0                     0
# 3                         0                       0                     0
# 4                         0                       0                     0
# 5                         0                       0                     0
# 6                         0                       4                    34
# 7                         0                       0                     0
# 8                         0                       0                     0
# 9                         0                       1                     4
# 10                        0                       0                     0
# 11                        0                       0                     0
# 12                        0                       0                     0
# 13                        0                       0                     0
# 14                        0                       0                     2
# 15                        0                       0                     0
# 16                        0                       0                     0
# 17                        0                       0                     0
# 18                        0                       0                     0
# 19                        0                       0                     0
# 20                        0                       0                     0
# 21                        0                       1                     0
# 22                        3                      50                   137
# 23                        0                       0                     0
# 24                        0                       0                     0
# 25                        0                       0                     0
# 26                        0                       0                     0
# 27                        0                       0                     0
# 28                        0                       1                     3
# 29                        0                       0                     0
# ...                     ...                     ...                   ...
# 12980                     0                       0                     1
# 12981                     0                       0                     0
# 12982                     0                       0                     0
# 12983                     0                       0                     0
# 12984                     0                       0                     0
# 12985                     0                       0                     0
# 12986                     0                       0                     0
# 12987                     0                       0                     0
# 12988                     0                       1                     0
# 12989                     0                       0                     1
# 12990                     0                       0                     0
# 12991                     0                       0                     0
# 12992                     0                       0                     0
# 12993                     0                       0                     0
# 12994                     0                       0                     0
# 12995                     0                       0                     0
# 12996                     0                       0                     0
# 12997                     0                       0                     0
# 12998                     0                       0                     0
# 12999                     0                       0                     0
# 13000                     0                       0                     0
# 13001                     0                       0                     0
# 13002                     0                       0                     0
# 13003                     0                       0                     0
# 13004                     0                       0                     0
# 13005                     0                       0                     0
# 13006                     0                       0                     0
# 13007                     0                       0                     0
# 13008                     0                       0                     0
# 13009                     0                       0                     1
#
#        Total.Uninjured Weather.Condition Broad.Phase.of.Flight  \
# 0                  588               VMC              STANDING
# 1                  588               VMC                  TAXI
# 2                  501               VMC              STANDING
# 3                  501               VMC                  TAXI
# 4                  454               VMC              STANDING
# 5                  454               VMC                  TAXI
# 6                  384               NaN               DESCENT
# 7                  394               NaN               TAKEOFF
# 8                  393               VMC               TAKEOFF
# 9                  380               VMC                 CLIMB
# 10                 368               VMC                  TAXI
# 11                 367               UNK                CRUISE
# 12                 365               NaN               LANDING
# 13                 352               VMC                  TAXI
# 14                 338               VMC               LANDING
# 15                 339               VMC                  TAXI
# 16                 339               VMC                  TAXI
# 17                 324               VMC              APPROACH
# 18                 324               VMC              APPROACH
# 19                 324               VMC              STANDING
# 20                 324               VMC                  TAXI
# 21                 311               VMC              STANDING
# 22                 117               VMC              APPROACH
# 23                 306               VMC               DESCENT
# 24                 301               VMC              STANDING
# 25                 301               VMC                  TAXI
# 26                 298               VMC                  TAXI
# 27                 298               VMC                  TAXI
# 28                 291               VMC                CRUISE
# 29                 294               VMC              STANDING
# ...                ...               ...                   ...
# 12980                0               VMC               LANDING
# 12981                1               VMC               LANDING
# 12982                1               VMC                  TAXI
# 12983                1               VMC               LANDING
# 12984                1               VMC              APPROACH
# 12985                1               VMC               TAKEOFF
# 12986                1               VMC               DESCENT
# 12987                1               VMC               LANDING
# 12988                0               VMC               LANDING
# 12989                0               VMC               LANDING
# 12990                1               VMC               LANDING
# 12991                1               VMC              APPROACH
# 12992                1               IMC               DESCENT
# 12993                1               VMC               TAKEOFF
# 12994                1               VMC           MANEUVERING
# 12995                1               VMC             GO-AROUND
# 12996                1               VMC               TAKEOFF
# 12997                1               VMC               DESCENT
# 12998                1               VMC               TAKEOFF
# 12999                1               VMC               LANDING
# 13000                1               VMC              APPROACH
# 13001                1               VMC               LANDING
# 13002                1               VMC              APPROACH
# 13003                1               VMC                  TAXI
# 13004                1               VMC                CRUISE
# 13005                1               VMC                CRUISE
# 13006                1               VMC              APPROACH
# 13007                1               VMC               TAKEOFF
# 13008                1               VMC                  TAXI
# 13009                0               IMC                CRUISE
#
#        Total.Passengers
# 0                   588
# 1                   588
# 2                   501
# 3                   501
# 4                   454
# 5                   454
# 6                   422
# 7                   394
# 8                   393
# 9                   385
# 10                  368
# 11                  367
# 12                  365
# 13                  352
# 14                  340
# 15                  339
# 16                  339
# 17                  324
# 18                  324
# 19                  324
# 20                  324
# 21                  312
# 22                  307
# 23                  306
# 24                  301
# 25                  301
# 26                  298
# 27                  298
# 28                  295
# 29                  294
# ...                 ...
# 12980                 1
# 12981                 1
# 12982                 1
# 12983                 1
# 12984                 1
# 12985                 1
# 12986                 1
# 12987                 1
# 12988                 1
# 12989                 1
# 12990                 1
# 12991                 1
# 12992                 1
# 12993                 1
# 12994                 1
# 12995                 1
# 12996                 1
# 12997                 1
# 12998                 1
# 12999                 1
# 13000                 1
# 13001                 1
# 13002                 1
# 13003                 1
# 13004                 1
# 13005                 1
# 13006                 1
# 13007                 1
# 13008                 1
# 13009                 1
#
# [13010 rows x 15 columns]

# %%
for index, row in aviationData.iterrows():
    if(aviationData.at[index, 'Weather.Condition'] == 'UNK'):
        aviationData.at[index, 'Weather.Condition'] = np.nan

# %% [markdown]
# # Predicting Missing Weather using AdaBoost

# %%
sb.catplot(y = 'Weather.Condition', data = aviationData, kind = "count", height = 5, aspect = 4)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
finaltest = pd.DataFrame(aviationData[aviationData['Weather.Condition'].isnull()])
training = pd.DataFrame(aviationData[aviationData['Weather.Condition'].notnull()])

# %%
y = pd.DataFrame(training["Weather.Condition"])
X = pd.DataFrame(training[["Total.Fatal.Injuries", "Total.Serious.Injuries","Total.Minor.Injuries","Total.Uninjured","Total.Passengers"]])
# remap weather condition, IMC = true, VMC = false
for index, row in y.iterrows():
    if(y.at[index,'Weather.Condition'] == 'IMC'):
        y.at[index, 'Weather.Condition'] = True;
    else:
        y.at[index, 'Weather.Condition'] = False;
        
y['Weather.Condition'] = y['Weather.Condition'].astype('bool')

# %%
# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (11232, 1) (11232, 5)
# Test Set  : (1249, 1) (1249, 5)

# %%
# Basse Decision tree
dectree = DecisionTreeClassifier(criterion = 'entropy',max_depth = 3)  
dectree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
#Boosting the base tree with AdaBoost
AdaBoost = AdaBoostClassifier(base_estimator = dectree, n_estimators = 11232, learning_rate = 1)
boostModel = AdaBoost.fit(X_train,y_train)
pred = boostModel.predict(X_test)

predictions = metrics.accuracy_score(y_test,pred)

print("prediction accuracy is: ",predictions*100,"%")
# Out:
# C:\Users\Zhimin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# prediction accuracy is:  91.99359487590073 %

# %%
unk = pd.DataFrame(finaltest[["Total.Fatal.Injuries", "Total.Serious.Injuries","Total.Minor.Injuries","Total.Uninjured","Total.Passengers"]])

actualPred = boostModel.predict(unk)
actualPred = pd.DataFrame(actualPred, columns = ["Weather.Condition"], index = finaltest.index)
finaltest["Weather.Condition"] = actualPred["Weather.Condition"].values

# %%
finaltest['Weather.Condition'] = finaltest['Weather.Condition'].astype('object')

for index, row in finaltest.iterrows():
    if(finaltest.at[index,'Weather.Condition'] == 'True'):
        finaltest.at[index, 'Weather.Condition'] = 'IMC';
    else:
        finaltest.at[index, 'Weather.Condition'] = "VMC";

# %%
frames = [training,finaltest]
aviationData = pd.concat(frames)

# %%
aviationData = aviationData.dropna()
aviationData.to_csv('Intermediate.csv')

# %%
aviationData.describe()
# Out:
#            Altitude      Latitude     Longitude  Number.of.Engines  \
# count  12954.000000  12954.000000  12954.000000       12954.000000
# mean    2449.136599     39.343807    -97.432821           1.283851
# std     4303.371335      9.395078     29.881973           0.673487
# min      -65.700000    -78.016945   -171.734722           1.000000
# 25%      195.200000     35.122501   -111.480139           1.000000
# 50%      367.200000     39.164723    -96.610412           1.000000
# 75%     1341.200000     41.681459    -84.766320           1.000000
# max    12534.600000     72.779167    165.147777           4.000000
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# count          12954.000000            12954.000000          12954.000000
# mean               0.414775                0.173614              0.309788
# std                3.409520                0.765511              1.835256
# min                0.000000                0.000000              0.000000
# 25%                0.000000                0.000000              0.000000
# 50%                0.000000                0.000000              0.000000
# 75%                0.000000                0.000000              0.000000
# max              228.000000               50.000000            137.000000
#
#        Total.Uninjured  Total.Passengers
# count     12954.000000      12954.000000
# mean          5.720241          6.618419
# std          29.584821         30.029360
# min           0.000000          1.000000
# 25%           0.000000          1.000000
# 50%           1.000000          2.000000
# 75%           2.000000          3.000000
# max         588.000000        588.000000

# %% [markdown]
# # Univariate Exploratory analysis

# %% [markdown]
# ### Categorical Data

# %%
#Converting number of engines to categorical
aviationData['Number.of.Engines'] = aviationData['Number.of.Engines'].astype('object')

# %%
aviationCatData = pd.DataFrame(aviationData[['Injury.Severity', 'Aircraft.Damage', 'Number.of.Engines', 'Engine.Type', 'Purpose.of.Flight', 'Weather.Condition', 'Broad.Phase.of.Flight', ]])

# %%
aviationCatData.columns = ['InjurySeverity', 'AircraftDamage', 'EngineCount', 'EngineType', 'FlightPurpose', 'Weather', 'Phase']

# %%
aviationCatData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12954 entries, 0 to 12952
# Data columns (total 7 columns):
# InjurySeverity    12954 non-null object
# AircraftDamage    12954 non-null object
# EngineCount       12954 non-null object
# EngineType        12954 non-null object
# FlightPurpose     12954 non-null object
# Weather           12954 non-null object
# Phase             12954 non-null object
# dtypes: object(7)
# memory usage: 809.6+ KB

# %%
aviationCatData.shape
# Out:
# (12954, 7)

# %%
aviationCatData.head()
# Out:
#   InjurySeverity AircraftDamage EngineCount EngineType FlightPurpose Weather  \
# 0       INCIDENT          MINOR           3  TURBO FAN       UNKNOWN     VMC
# 1       INCIDENT          MINOR           4  TURBO FAN       UNKNOWN     VMC
# 2      NON-FATAL    SUBSTANTIAL           2  TURBO FAN       UNKNOWN     VMC
# 3      NON-FATAL          MINOR           2  TURBO FAN       UNKNOWN     VMC
# 4      NON-FATAL    SUBSTANTIAL           2  TURBO FAN       UNKNOWN     VMC
#
#       Phase
# 0  STANDING
# 1      TAXI
# 2  STANDING
# 3      TAXI
# 4  STANDING

# %% [markdown]
# #### Injury Severity

# %%
pd.DataFrame(aviationCatData.InjurySeverity.value_counts())
# Out:
#            InjurySeverity
# NON-FATAL           10341
# FATAL                2177
# INCIDENT              436

# %%
plt.figure(figsize = (5, 2.5))
plt.subplot(1, 2, 1);aviationCatData.InjurySeverity.value_counts(normalize = True).plot(kind = 'bar'); plt.title('Injury Severity')
# Out:
# Text(0.5, 1.0, 'Injury Severity')

# %% [markdown]
# #### Aircraft Damage

# %%
pd.DataFrame(aviationCatData.AircraftDamage.value_counts())
# Out:
#              AircraftDamage
# SUBSTANTIAL           10837
# DESTROYED              1680
# MINOR                   437

# %%
plt.figure(figsize = (5, 2.5))
plt.subplot(1, 2, 1);aviationCatData.AircraftDamage.value_counts(normalize = True).plot(kind = 'bar'); plt.title('Aircraft Damage')
# Out:
# Text(0.5, 1.0, 'Aircraft Damage')

# %% [markdown]
# #### Number of Engines

# %%
pd.DataFrame(aviationCatData.EngineCount.value_counts())
# Out:
#    EngineCount
# 1        10371
# 2         2016
# 4          527
# 3           40

# %%
plt.figure(figsize = (5, 2.5))
plt.subplot(1, 2, 1);aviationCatData.EngineCount.value_counts(normalize = True).plot(kind = 'bar'); plt.title('Number of Engines')
# Out:
# Text(0.5, 1.0, 'Number of Engines')

# %% [markdown]
# #### Engine Type

# %%
pd.DataFrame(aviationCatData.EngineType.value_counts())
# Out:
#                EngineType
# RECIPROCATING       11286
# TURBO PROP            599
# TURBO FAN             547
# UNKNOWN               406
# TURBO JET             116

# %%
plt.figure(figsize = (5, 2.5))
plt.subplot(1, 2, 1);aviationCatData.EngineType.value_counts(normalize = True).plot(kind = 'bar'); plt.title('Engine Type')
# Out:
# Text(0.5, 1.0, 'Engine Type')

# %% [markdown]
# #### Purpose of Flight

# %%
pd.DataFrame(aviationCatData.FlightPurpose.value_counts())
# Out:
#                      FlightPurpose
# PERSONAL                     10014
# UNKNOWN                       1587
# BUSINESS                       632
# POSITIONING                    249
# FERRY                          137
# EXECUTIVE/CORPORATE            112
# PUBLIC AIRCRAFT                101
# OTHER WORK USE                  92
# FLIGHT TEST                     86

# %%
plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1);aviationCatData.FlightPurpose.value_counts(normalize = True).plot(kind = 'bar'); plt.title('Purpose of Flight')
# Out:
# Text(0.5, 1.0, 'Purpose of Flight')

# %% [markdown]
# #### Weather Condition

# %%
pd.DataFrame(aviationCatData.Weather.value_counts())
# Out:
#      Weather
# VMC    12026
# IMC      928

# %%
plt.figure(figsize = (15, 7))
plt.subplot(1, 2, 1)
aviationCatData.AircraftDamage.value_counts(normalize = True).plot(kind = 'bar'); plt.title('Weather Condition')
# Out:
# Text(0.5, 1.0, 'Weather Condition')

# %% [markdown]
# #### Phase of Flight

# %%
pd.DataFrame(aviationCatData.Phase.value_counts())
# Out:
#              Phase
# LANDING       4755
# TAKEOFF       2940
# APPROACH      1404
# CRUISE        1139
# MANEUVERING    859
# TAXI           545
# DESCENT        421
# CLIMB          334
# GO-AROUND      303
# STANDING       254

# %%
plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1);aviationCatData.Phase.value_counts(normalize = True).plot(kind = 'bar'); plt.title('Phase of Flight')
# Out:
# Text(0.5, 1.0, 'Phase of Flight')

# %%
compare = aviationCatData.groupby("AircraftDamage").InjurySeverity.value_counts(normalize = True)
compare.unstack()
# Out:
# InjurySeverity     FATAL  INCIDENT  NON-FATAL
# AircraftDamage
# DESTROYED       0.698214  0.027381   0.274405
# MINOR           0.038902  0.672769   0.288330
# SUBSTANTIAL     0.091077  0.008859   0.900065

# %%
plt.figure(figsize = (20, 10))
compare.unstack().plot(kind='bar', stacked = True); plt.title('Injury severity at each level of aircraft damage')
# Out:
# Text(0.5, 1.0, 'Injury severity at each level of aircraft damage')

# %%
compare = aviationCatData.groupby("Phase").InjurySeverity.value_counts(normalize = True)
compare.unstack()
# Out:
# InjurySeverity     FATAL  INCIDENT  NON-FATAL
# Phase
# APPROACH        0.277778  0.038462   0.683761
# CLIMB           0.323353  0.098802   0.577844
# CRUISE          0.324846  0.040386   0.634767
# DESCENT         0.270784  0.042755   0.686461
# GO-AROUND       0.267327  0.026403   0.706271
# LANDING         0.014932  0.025026   0.960042
# MANEUVERING     0.566938  0.008149   0.424913
# STANDING        0.074803  0.059055   0.866142
# TAKEOFF         0.181633  0.034354   0.784014
# TAXI            0.005505  0.064220   0.930275

# %%
plt.figure(figsize = (20, 10))
compare.unstack().plot(kind='bar', stacked = True); plt.title('Injury severity at different phases')
# Out:
# Text(0.5, 1.0, 'Injury severity at different phases')

# %%
compare = aviationCatData.groupby("Weather").AircraftDamage.value_counts(normalize = True)
compare.unstack()
# Out:
# AircraftDamage  DESTROYED     MINOR  SUBSTANTIAL
# Weather
# IMC              0.411638  0.034483     0.553879
# VMC              0.107933  0.033677     0.858390

# %%
plt.figure(figsize = (15, 10))
compare.unstack().plot(kind='bar', stacked = True); plt.title('Aircraft Damage at each weather condition')
# Out:
# Text(0.5, 1.0, 'Aircraft Damage at each weather condition')

# %%
compare = aviationCatData.groupby("Phase").AircraftDamage.value_counts(normalize = True)
compare.unstack()
# Out:
# AircraftDamage  DESTROYED     MINOR  SUBSTANTIAL
# Phase
# APPROACH         0.170940  0.027066     0.801994
# CLIMB            0.269461  0.053892     0.676647
# CRUISE           0.320457  0.028095     0.651449
# DESCENT          0.182898  0.028504     0.788599
# GO-AROUND        0.181518  0.029703     0.788779
# LANDING          0.029863  0.020820     0.949317
# MANEUVERING      0.327125  0.011641     0.661234
# STANDING         0.043307  0.251969     0.704724
# TAKEOFF          0.140476  0.020748     0.838776
# TAXI             0.011009  0.172477     0.816514

# %%
plt.figure(figsize = (20, 10))
compare.unstack().plot(kind='bar', stacked = True); plt.title('Aircraft Damage at each phase')
# Out:
# Text(0.5, 1.0, 'Aircraft Damage at each phase')

# %%
compare = aviationCatData.groupby("Phase").InjurySeverity.value_counts(normalize = True)
compare.unstack()
plt.figure(figsize = (20, 10))
compare.unstack().plot(kind='bar', stacked = True); plt.title('Injury severity at different phases')

# %%
aviationCatData
# Out:
#       InjurySeverity AircraftDamage EngineCount     EngineType  \
# 0           INCIDENT          MINOR           3      TURBO FAN
# 1           INCIDENT          MINOR           4      TURBO FAN
# 2          NON-FATAL    SUBSTANTIAL           2      TURBO FAN
# 3          NON-FATAL          MINOR           2      TURBO FAN
# 4          NON-FATAL    SUBSTANTIAL           2      TURBO FAN
# 5          NON-FATAL          MINOR           2      TURBO FAN
# 8           INCIDENT          MINOR           3      TURBO FAN
# 9          NON-FATAL    SUBSTANTIAL           4      TURBO FAN
# 10          INCIDENT          MINOR           4      TURBO FAN
# 13         NON-FATAL    SUBSTANTIAL           2      TURBO FAN
# 14         NON-FATAL    SUBSTANTIAL           4      TURBO FAN
# 15         NON-FATAL    SUBSTANTIAL           2     TURBO PROP
# 16         NON-FATAL          MINOR           3      TURBO FAN
# 17          INCIDENT    SUBSTANTIAL           2        UNKNOWN
# 18          INCIDENT    SUBSTANTIAL           2        UNKNOWN
# 19          INCIDENT          MINOR           2      TURBO FAN
# 20          INCIDENT          MINOR           2      TURBO FAN
# 21         NON-FATAL          MINOR           2      TURBO FAN
# 22             FATAL      DESTROYED           2      TURBO FAN
# 23          INCIDENT    SUBSTANTIAL           3      TURBO FAN
# 24         NON-FATAL    SUBSTANTIAL           2      TURBO FAN
# 25         NON-FATAL          MINOR           2      TURBO FAN
# 26         NON-FATAL    SUBSTANTIAL           2      TURBO JET
# 27         NON-FATAL          MINOR           2      TURBO FAN
# 28         NON-FATAL      DESTROYED           2      TURBO FAN
# 29         NON-FATAL    SUBSTANTIAL           2      TURBO FAN
# 30         NON-FATAL          MINOR           2      TURBO FAN
# 31         NON-FATAL      DESTROYED           3      TURBO FAN
# 32         NON-FATAL          MINOR           2      TURBO FAN
# 33         NON-FATAL    SUBSTANTIAL           2      TURBO FAN
# ...              ...            ...         ...            ...
# 8975       NON-FATAL      DESTROYED           1  RECIPROCATING
# 9050       NON-FATAL    SUBSTANTIAL           2     TURBO PROP
# 9055       NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 9069       NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 9075       NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 9084       NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 9109       NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 9136       NON-FATAL    SUBSTANTIAL           1     TURBO PROP
# 9155       NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 9216       NON-FATAL    SUBSTANTIAL           4        UNKNOWN
# 9220        INCIDENT          MINOR           4        UNKNOWN
# 9286       NON-FATAL    SUBSTANTIAL           4        UNKNOWN
# 9317       NON-FATAL      DESTROYED           2        UNKNOWN
# 9592       NON-FATAL    SUBSTANTIAL           4        UNKNOWN
# 9616       NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 9791       NON-FATAL    SUBSTANTIAL           2  RECIPROCATING
# 10457      NON-FATAL          MINOR           2        UNKNOWN
# 11165      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12324      NON-FATAL    SUBSTANTIAL           4        UNKNOWN
# 12337      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12382      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12418      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12604      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12619      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12663      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12723      NON-FATAL      DESTROYED           1  RECIPROCATING
# 12804      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12871      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
# 12920      NON-FATAL    SUBSTANTIAL           2  RECIPROCATING
# 12952      NON-FATAL    SUBSTANTIAL           1  RECIPROCATING
#
#          FlightPurpose Weather     Phase
# 0              UNKNOWN     VMC  STANDING
# 1              UNKNOWN     VMC      TAXI
# 2              UNKNOWN     VMC  STANDING
# 3              UNKNOWN     VMC      TAXI
# 4              UNKNOWN     VMC  STANDING
# 5              UNKNOWN     VMC      TAXI
# 8              UNKNOWN     VMC   TAKEOFF
# 9              UNKNOWN     VMC     CLIMB
# 10             UNKNOWN     VMC      TAXI
# 13             UNKNOWN     VMC      TAXI
# 14             UNKNOWN     VMC   LANDING
# 15             UNKNOWN     VMC      TAXI
# 16             UNKNOWN     VMC      TAXI
# 17             UNKNOWN     VMC  APPROACH
# 18             UNKNOWN     VMC  APPROACH
# 19             UNKNOWN     VMC  STANDING
# 20             UNKNOWN     VMC      TAXI
# 21             UNKNOWN     VMC  STANDING
# 22             UNKNOWN     VMC  APPROACH
# 23             UNKNOWN     VMC   DESCENT
# 24             UNKNOWN     VMC  STANDING
# 25             UNKNOWN     VMC      TAXI
# 26             UNKNOWN     VMC      TAXI
# 27             UNKNOWN     VMC      TAXI
# 28             UNKNOWN     VMC    CRUISE
# 29             UNKNOWN     VMC  STANDING
# 30             UNKNOWN     VMC      TAXI
# 31             UNKNOWN     VMC   TAKEOFF
# 32             UNKNOWN     VMC      TAXI
# 33             UNKNOWN     VMC  STANDING
# ...                ...     ...       ...
# 8975           UNKNOWN     VMC    CRUISE
# 9050           UNKNOWN     VMC   LANDING
# 9055          PERSONAL     VMC   LANDING
# 9069          PERSONAL     VMC   LANDING
# 9075          PERSONAL     VMC   LANDING
# 9084          PERSONAL     VMC      TAXI
# 9109          PERSONAL     VMC   LANDING
# 9136           UNKNOWN     VMC   DESCENT
# 9155          PERSONAL     VMC   LANDING
# 9216           UNKNOWN     VMC   TAKEOFF
# 9220           UNKNOWN     VMC   TAKEOFF
# 9286           UNKNOWN     VMC   LANDING
# 9317       POSITIONING     VMC   TAKEOFF
# 9592           UNKNOWN     VMC   TAKEOFF
# 9616             FERRY     VMC    CRUISE
# 9791          PERSONAL     VMC   LANDING
# 10457          UNKNOWN     VMC  STANDING
# 11165            FERRY     VMC   TAKEOFF
# 12324  PUBLIC AIRCRAFT     VMC   LANDING
# 12337          UNKNOWN     VMC   LANDING
# 12382          UNKNOWN     VMC    CRUISE
# 12418         PERSONAL     VMC  APPROACH
# 12604         PERSONAL     VMC    CRUISE
# 12619          UNKNOWN     VMC   LANDING
# 12663         PERSONAL     VMC   LANDING
# 12723         PERSONAL     VMC   LANDING
# 12804         BUSINESS     VMC      TAXI
# 12871          UNKNOWN     VMC   LANDING
# 12920          UNKNOWN     VMC   TAKEOFF
# 12952          UNKNOWN     VMC   LANDING
#
# [12954 rows x 7 columns]

# %%
aviationData
# Out:
#        Altitude   Latitude   Longitude Injury.Severity Aircraft.Damage  \
# 0         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 1         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 2         202.7  41.968611  -87.907778       NON-FATAL     SUBSTANTIAL
# 3         202.7  41.968611  -87.907778       NON-FATAL           MINOR
# 4         215.4  35.213611  -80.948889       NON-FATAL     SUBSTANTIAL
# 5         215.4  35.213611  -80.948889       NON-FATAL           MINOR
# 8         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 9         332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 10          2.3  25.793333  -80.290555        INCIDENT           MINOR
# 13        124.0  47.449722 -122.311667       NON-FATAL     SUBSTANTIAL
# 14        367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 15        367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 16        367.2  39.164723  -96.610412       NON-FATAL           MINOR
# 17        519.5  41.983889  -87.663611        INCIDENT     SUBSTANTIAL
# 18        519.5  41.983889  -87.663611        INCIDENT     SUBSTANTIAL
# 19       1635.6  39.861667 -104.673056        INCIDENT           MINOR
# 20       1635.6  39.861667 -104.673056        INCIDENT           MINOR
# 21          3.1  37.618889 -122.374723       NON-FATAL           MINOR
# 22        697.8  37.613333 -122.363889           FATAL       DESTROYED
# 23        395.2  33.636666  -84.428056        INCIDENT     SUBSTANTIAL
# 24         18.3  38.900000  -77.033334       NON-FATAL     SUBSTANTIAL
# 25         18.3  38.900000  -77.033334       NON-FATAL           MINOR
# 26        304.8  33.636666  -84.428056       NON-FATAL     SUBSTANTIAL
# 27        304.8  33.636666  -84.428056       NON-FATAL           MINOR
# 28      10970.0  21.318611 -157.922500       NON-FATAL       DESTROYED
# 29          2.3  25.793333  -80.290555       NON-FATAL     SUBSTANTIAL
# 30          2.3  25.793333  -80.290555       NON-FATAL           MINOR
# 31        367.2  39.164723  -96.610412       NON-FATAL       DESTROYED
# 32          4.7  42.353333  -71.014444       NON-FATAL           MINOR
# 33          4.7  42.353333  -71.014444       NON-FATAL     SUBSTANTIAL
# ...         ...        ...         ...             ...             ...
# 8975    10932.0  21.715000  -98.608333       NON-FATAL       DESTROYED
# 9050     1090.3  45.807778 -108.542777       NON-FATAL     SUBSTANTIAL
# 9055      307.7  33.423056 -112.685555       NON-FATAL     SUBSTANTIAL
# 9069      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9075       74.8  48.498611 -122.662500       NON-FATAL     SUBSTANTIAL
# 9084      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9109      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9136      197.1 -20.889444  -49.388055       NON-FATAL     SUBSTANTIAL
# 9155      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9216        7.8  24.698055  -77.795555       NON-FATAL     SUBSTANTIAL
# 9220      367.2  39.164723  -96.610412        INCIDENT           MINOR
# 9286      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9317        1.3  16.257778  -61.262500       NON-FATAL       DESTROYED
# 9592      170.0  51.331389    0.032778       NON-FATAL     SUBSTANTIAL
# 9616    10967.0  31.252778  130.633056       NON-FATAL     SUBSTANTIAL
# 9791      160.0  48.751111    2.106389       NON-FATAL     SUBSTANTIAL
# 10457     367.2  39.164723  -96.610412       NON-FATAL           MINOR
# 11165     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12324     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12337     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12382   10604.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12418     332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12604   12129.6  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12619     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12663     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12723     367.2  39.164723  -96.610412       NON-FATAL       DESTROYED
# 12804     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12871     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12920     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12952     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
#
#       Number.of.Engines    Engine.Type Purpose.of.Flight  \
# 0                     3      TURBO FAN           UNKNOWN
# 1                     4      TURBO FAN           UNKNOWN
# 2                     2      TURBO FAN           UNKNOWN
# 3                     2      TURBO FAN           UNKNOWN
# 4                     2      TURBO FAN           UNKNOWN
# 5                     2      TURBO FAN           UNKNOWN
# 8                     3      TURBO FAN           UNKNOWN
# 9                     4      TURBO FAN           UNKNOWN
# 10                    4      TURBO FAN           UNKNOWN
# 13                    2      TURBO FAN           UNKNOWN
# 14                    4      TURBO FAN           UNKNOWN
# 15                    2     TURBO PROP           UNKNOWN
# 16                    3      TURBO FAN           UNKNOWN
# 17                    2        UNKNOWN           UNKNOWN
# 18                    2        UNKNOWN           UNKNOWN
# 19                    2      TURBO FAN           UNKNOWN
# 20                    2      TURBO FAN           UNKNOWN
# 21                    2      TURBO FAN           UNKNOWN
# 22                    2      TURBO FAN           UNKNOWN
# 23                    3      TURBO FAN           UNKNOWN
# 24                    2      TURBO FAN           UNKNOWN
# 25                    2      TURBO FAN           UNKNOWN
# 26                    2      TURBO JET           UNKNOWN
# 27                    2      TURBO FAN           UNKNOWN
# 28                    2      TURBO FAN           UNKNOWN
# 29                    2      TURBO FAN           UNKNOWN
# 30                    2      TURBO FAN           UNKNOWN
# 31                    3      TURBO FAN           UNKNOWN
# 32                    2      TURBO FAN           UNKNOWN
# 33                    2      TURBO FAN           UNKNOWN
# ...                 ...            ...               ...
# 8975                  1  RECIPROCATING           UNKNOWN
# 9050                  2     TURBO PROP           UNKNOWN
# 9055                  1  RECIPROCATING          PERSONAL
# 9069                  1  RECIPROCATING          PERSONAL
# 9075                  1  RECIPROCATING          PERSONAL
# 9084                  1  RECIPROCATING          PERSONAL
# 9109                  1  RECIPROCATING          PERSONAL
# 9136                  1     TURBO PROP           UNKNOWN
# 9155                  1  RECIPROCATING          PERSONAL
# 9216                  4        UNKNOWN           UNKNOWN
# 9220                  4        UNKNOWN           UNKNOWN
# 9286                  4        UNKNOWN           UNKNOWN
# 9317                  2        UNKNOWN       POSITIONING
# 9592                  4        UNKNOWN           UNKNOWN
# 9616                  1  RECIPROCATING             FERRY
# 9791                  2  RECIPROCATING          PERSONAL
# 10457                 2        UNKNOWN           UNKNOWN
# 11165                 1  RECIPROCATING             FERRY
# 12324                 4        UNKNOWN   PUBLIC AIRCRAFT
# 12337                 1  RECIPROCATING           UNKNOWN
# 12382                 1  RECIPROCATING           UNKNOWN
# 12418                 1  RECIPROCATING          PERSONAL
# 12604                 1  RECIPROCATING          PERSONAL
# 12619                 1  RECIPROCATING           UNKNOWN
# 12663                 1  RECIPROCATING          PERSONAL
# 12723                 1  RECIPROCATING          PERSONAL
# 12804                 1  RECIPROCATING          BUSINESS
# 12871                 1  RECIPROCATING           UNKNOWN
# 12920                 2  RECIPROCATING           UNKNOWN
# 12952                 1  RECIPROCATING           UNKNOWN
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                         0                       0                     0
# 1                         0                       0                     0
# 2                         0                       0                     0
# 3                         0                       0                     0
# 4                         0                       0                     0
# 5                         0                       0                     0
# 8                         0                       0                     0
# 9                         0                       1                     4
# 10                        0                       0                     0
# 13                        0                       0                     0
# 14                        0                       0                     2
# 15                        0                       0                     0
# 16                        0                       0                     0
# 17                        0                       0                     0
# 18                        0                       0                     0
# 19                        0                       0                     0
# 20                        0                       0                     0
# 21                        0                       1                     0
# 22                        3                      50                   137
# 23                        0                       0                     0
# 24                        0                       0                     0
# 25                        0                       0                     0
# 26                        0                       0                     0
# 27                        0                       0                     0
# 28                        0                       1                     3
# 29                        0                       0                     0
# 30                        0                       0                     0
# 31                        0                       1                     9
# 32                        0                       0                     0
# 33                        0                       0                     0
# ...                     ...                     ...                   ...
# 8975                      0                       1                     0
# 9050                      0                       0                     0
# 9055                      0                       1                     0
# 9069                      0                       0                     0
# 9075                      0                       0                     0
# 9084                      0                       1                     0
# 9109                      0                       0                     0
# 9136                      0                       0                     0
# 9155                      0                       1                     0
# 9216                      0                       0                     0
# 9220                      0                       0                     0
# 9286                      0                       0                     1
# 9317                      0                       0                     0
# 9592                      0                       0                     0
# 9616                      0                       0                     1
# 9791                      0                       0                     0
# 10457                     0                       1                     0
# 11165                     0                       0                     0
# 12324                     0                       0                     0
# 12337                     0                       0                     0
# 12382                     0                       0                     1
# 12418                     0                       0                     0
# 12604                     0                       0                     0
# 12619                     0                       0                     0
# 12663                     0                       0                     0
# 12723                     0                       0                     0
# 12804                     0                       0                     0
# 12871                     0                       0                     0
# 12920                     0                       0                     1
# 12952                     0                       0                     0
#
#        Total.Uninjured Weather.Condition Broad.Phase.of.Flight  \
# 0                  588               VMC              STANDING
# 1                  588               VMC                  TAXI
# 2                  501               VMC              STANDING
# 3                  501               VMC                  TAXI
# 4                  454               VMC              STANDING
# 5                  454               VMC                  TAXI
# 8                  393               VMC               TAKEOFF
# 9                  380               VMC                 CLIMB
# 10                 368               VMC                  TAXI
# 13                 352               VMC                  TAXI
# 14                 338               VMC               LANDING
# 15                 339               VMC                  TAXI
# 16                 339               VMC                  TAXI
# 17                 324               VMC              APPROACH
# 18                 324               VMC              APPROACH
# 19                 324               VMC              STANDING
# 20                 324               VMC                  TAXI
# 21                 311               VMC              STANDING
# 22                 117               VMC              APPROACH
# 23                 306               VMC               DESCENT
# 24                 301               VMC              STANDING
# 25                 301               VMC                  TAXI
# 26                 298               VMC                  TAXI
# 27                 298               VMC                  TAXI
# 28                 291               VMC                CRUISE
# 29                 294               VMC              STANDING
# 30                 294               VMC                  TAXI
# 31                 282               VMC               TAKEOFF
# 32                 291               VMC                  TAXI
# 33                 291               VMC              STANDING
# ...                ...               ...                   ...
# 8975                 0               VMC                CRUISE
# 9050                 1               VMC               LANDING
# 9055                 0               VMC               LANDING
# 9069                 1               VMC               LANDING
# 9075                 1               VMC               LANDING
# 9084                 0               VMC                  TAXI
# 9109                 1               VMC               LANDING
# 9136                 1               VMC               DESCENT
# 9155                 0               VMC               LANDING
# 9216                 1               VMC               TAKEOFF
# 9220                 1               VMC               TAKEOFF
# 9286                 0               VMC               LANDING
# 9317                 1               VMC               TAKEOFF
# 9592                 1               VMC               TAKEOFF
# 9616                 0               VMC                CRUISE
# 9791                 1               VMC               LANDING
# 10457                0               VMC              STANDING
# 11165                1               VMC               TAKEOFF
# 12324                1               VMC               LANDING
# 12337                1               VMC               LANDING
# 12382                0               VMC                CRUISE
# 12418                1               VMC              APPROACH
# 12604                1               VMC                CRUISE
# 12619                1               VMC               LANDING
# 12663                1               VMC               LANDING
# 12723                1               VMC               LANDING
# 12804                1               VMC                  TAXI
# 12871                1               VMC               LANDING
# 12920                0               VMC               TAKEOFF
# 12952                1               VMC               LANDING
#
#        Total.Passengers
# 0                   588
# 1                   588
# 2                   501
# 3                   501
# 4                   454
# 5                   454
# 8                   393
# 9                   385
# 10                  368
# 13                  352
# 14                  340
# 15                  339
# 16                  339
# 17                  324
# 18                  324
# 19                  324
# 20                  324
# 21                  312
# 22                  307
# 23                  306
# 24                  301
# 25                  301
# 26                  298
# 27                  298
# 28                  295
# 29                  294
# 30                  294
# 31                  292
# 32                  291
# 33                  291
# ...                 ...
# 8975                  1
# 9050                  1
# 9055                  1
# 9069                  1
# 9075                  1
# 9084                  1
# 9109                  1
# 9136                  1
# 9155                  1
# 9216                  1
# 9220                  1
# 9286                  1
# 9317                  1
# 9592                  1
# 9616                  1
# 9791                  1
# 10457                 1
# 11165                 1
# 12324                 1
# 12337                 1
# 12382                 1
# 12418                 1
# 12604                 1
# 12619                 1
# 12663                 1
# 12723                 1
# 12804                 1
# 12871                 1
# 12920                 1
# 12952                 1
#
# [12954 rows x 15 columns]

# %% [markdown]
# ### Numeric Data

# %%
aviationNumData = pd.DataFrame(aviationData[['Altitude', 'Latitude', 'Longitude', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured', 'Total.Passengers']])

# %%
aviationNumData.head()
# Out:
#    Altitude   Latitude  Longitude  Total.Fatal.Injuries  \
# 0     367.2  39.164723 -96.610412                     0
# 1     367.2  39.164723 -96.610412                     0
# 2     202.7  41.968611 -87.907778                     0
# 3     202.7  41.968611 -87.907778                     0
# 4     215.4  35.213611 -80.948889                     0
#
#    Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 0                       0                     0              588
# 1                       0                     0              588
# 2                       0                     0              501
# 3                       0                     0              501
# 4                       0                     0              454
#
#    Total.Passengers
# 0               588
# 1               588
# 2               501
# 3               501
# 4               454

# %%
aviationNumData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12954 entries, 0 to 12952
# Data columns (total 8 columns):
# Altitude                  12954 non-null float64
# Latitude                  12954 non-null float64
# Longitude                 12954 non-null float64
# Total.Fatal.Injuries      12954 non-null int64
# Total.Serious.Injuries    12954 non-null int64
# Total.Minor.Injuries      12954 non-null int64
# Total.Uninjured           12954 non-null int64
# Total.Passengers          12954 non-null int64
# dtypes: float64(3), int64(5)
# memory usage: 910.8 KB

# %%
aviationNumData.describe()
# Out:
#            Altitude      Latitude     Longitude  Total.Fatal.Injuries  \
# count  12954.000000  12954.000000  12954.000000          12954.000000
# mean    2449.136599     39.343807    -97.432821              0.414775
# std     4303.371335      9.395078     29.881973              3.409520
# min      -65.700000    -78.016945   -171.734722              0.000000
# 25%      195.200000     35.122501   -111.480139              0.000000
# 50%      367.200000     39.164723    -96.610412              0.000000
# 75%     1341.200000     41.681459    -84.766320              0.000000
# max    12534.600000     72.779167    165.147777            228.000000
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# count            12954.000000          12954.000000     12954.000000
# mean                 0.173614              0.309788         5.720241
# std                  0.765511              1.835256        29.584821
# min                  0.000000              0.000000         0.000000
# 25%                  0.000000              0.000000         0.000000
# 50%                  0.000000              0.000000         1.000000
# 75%                  0.000000              0.000000         2.000000
# max                 50.000000            137.000000       588.000000
#
#        Total.Passengers
# count      12954.000000
# mean           6.618419
# std           30.029360
# min            1.000000
# 25%            1.000000
# 50%            2.000000
# 75%            3.000000
# max          588.000000

# %%
count = 0
f, axes = plt.subplots(8, 3, figsize=(42, 25))

for i in aviationNumData:
    sb.boxplot(aviationData[i], orient = "h", ax = axes[count,0])
    sb.distplot(aviationData[i], kde = False, ax = axes[count,1])
    sb.violinplot(aviationData[i], ax = axes[count,2])
    count += 1

# %%
print(aviationNumData.corr())
f, axes = plt.subplots(1, 1, figsize=(20, 20))
sb.heatmap(aviationNumData.corr(), vmin = -1, vmax = 1, linewidths = 1, annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
#                         Altitude  Latitude  Longitude  Total.Fatal.Injuries  \
# Altitude                1.000000 -0.050062   0.035091              0.059270
# Latitude               -0.050062  1.000000  -0.455827             -0.032237
# Longitude               0.035091 -0.455827   1.000000              0.022086
# Total.Fatal.Injuries    0.059270 -0.032237   0.022086              1.000000
# Total.Serious.Injuries  0.036065 -0.036312   0.018051              0.198422
# Total.Minor.Injuries    0.005459 -0.004952  -0.005649             -0.007162
# Total.Uninjured        -0.050747 -0.029393   0.032807             -0.021292
# Total.Passengers       -0.042013 -0.033847   0.034944              0.097184
#
#                         Total.Serious.Injuries  Total.Minor.Injuries  \
# Altitude                              0.036065              0.005459
# Latitude                             -0.036312             -0.004952
# Longitude                             0.018051             -0.005649
# Total.Fatal.Injuries                  0.198422             -0.007162
# Total.Serious.Injuries                1.000000              0.460017
# Total.Minor.Injuries                  0.460017              1.000000
# Total.Uninjured                       0.048355              0.099347
# Total.Passengers                      0.123774              0.169905
#
#                         Total.Uninjured  Total.Passengers
# Altitude                      -0.050747         -0.042013
# Latitude                      -0.029393         -0.033847
# Longitude                      0.032807          0.034944
# Total.Fatal.Injuries          -0.021292          0.097184
# Total.Serious.Injuries         0.048355          0.123774
# Total.Minor.Injuries           0.099347          0.169905
# Total.Uninjured                1.000000          0.990083
# Total.Passengers               0.990083          1.000000

# %%
sb.pairplot(data = aviationNumData)

# %% [markdown]
# ## Visualizing relationships between numeric and Categorical Data

# %%
aviationData
# Out:
#        Altitude   Latitude   Longitude Injury.Severity Aircraft.Damage  \
# 0         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 1         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 2         202.7  41.968611  -87.907778       NON-FATAL     SUBSTANTIAL
# 3         202.7  41.968611  -87.907778       NON-FATAL           MINOR
# 4         215.4  35.213611  -80.948889       NON-FATAL     SUBSTANTIAL
# 5         215.4  35.213611  -80.948889       NON-FATAL           MINOR
# 8         367.2  39.164723  -96.610412        INCIDENT           MINOR
# 9         332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 10          2.3  25.793333  -80.290555        INCIDENT           MINOR
# 13        124.0  47.449722 -122.311667       NON-FATAL     SUBSTANTIAL
# 14        367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 15        367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 16        367.2  39.164723  -96.610412       NON-FATAL           MINOR
# 17        519.5  41.983889  -87.663611        INCIDENT     SUBSTANTIAL
# 18        519.5  41.983889  -87.663611        INCIDENT     SUBSTANTIAL
# 19       1635.6  39.861667 -104.673056        INCIDENT           MINOR
# 20       1635.6  39.861667 -104.673056        INCIDENT           MINOR
# 21          3.1  37.618889 -122.374723       NON-FATAL           MINOR
# 22        697.8  37.613333 -122.363889           FATAL       DESTROYED
# 23        395.2  33.636666  -84.428056        INCIDENT     SUBSTANTIAL
# 24         18.3  38.900000  -77.033334       NON-FATAL     SUBSTANTIAL
# 25         18.3  38.900000  -77.033334       NON-FATAL           MINOR
# 26        304.8  33.636666  -84.428056       NON-FATAL     SUBSTANTIAL
# 27        304.8  33.636666  -84.428056       NON-FATAL           MINOR
# 28      10970.0  21.318611 -157.922500       NON-FATAL       DESTROYED
# 29          2.3  25.793333  -80.290555       NON-FATAL     SUBSTANTIAL
# 30          2.3  25.793333  -80.290555       NON-FATAL           MINOR
# 31        367.2  39.164723  -96.610412       NON-FATAL       DESTROYED
# 32          4.7  42.353333  -71.014444       NON-FATAL           MINOR
# 33          4.7  42.353333  -71.014444       NON-FATAL     SUBSTANTIAL
# ...         ...        ...         ...             ...             ...
# 8975    10932.0  21.715000  -98.608333       NON-FATAL       DESTROYED
# 9050     1090.3  45.807778 -108.542777       NON-FATAL     SUBSTANTIAL
# 9055      307.7  33.423056 -112.685555       NON-FATAL     SUBSTANTIAL
# 9069      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9075       74.8  48.498611 -122.662500       NON-FATAL     SUBSTANTIAL
# 9084      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9109      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9136      197.1 -20.889444  -49.388055       NON-FATAL     SUBSTANTIAL
# 9155      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9216        7.8  24.698055  -77.795555       NON-FATAL     SUBSTANTIAL
# 9220      367.2  39.164723  -96.610412        INCIDENT           MINOR
# 9286      367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 9317        1.3  16.257778  -61.262500       NON-FATAL       DESTROYED
# 9592      170.0  51.331389    0.032778       NON-FATAL     SUBSTANTIAL
# 9616    10967.0  31.252778  130.633056       NON-FATAL     SUBSTANTIAL
# 9791      160.0  48.751111    2.106389       NON-FATAL     SUBSTANTIAL
# 10457     367.2  39.164723  -96.610412       NON-FATAL           MINOR
# 11165     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12324     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12337     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12382   10604.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12418     332.8  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12604   12129.6  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12619     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12663     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12723     367.2  39.164723  -96.610412       NON-FATAL       DESTROYED
# 12804     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12871     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12920     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
# 12952     367.2  39.164723  -96.610412       NON-FATAL     SUBSTANTIAL
#
#       Number.of.Engines    Engine.Type Purpose.of.Flight  \
# 0                     3      TURBO FAN           UNKNOWN
# 1                     4      TURBO FAN           UNKNOWN
# 2                     2      TURBO FAN           UNKNOWN
# 3                     2      TURBO FAN           UNKNOWN
# 4                     2      TURBO FAN           UNKNOWN
# 5                     2      TURBO FAN           UNKNOWN
# 8                     3      TURBO FAN           UNKNOWN
# 9                     4      TURBO FAN           UNKNOWN
# 10                    4      TURBO FAN           UNKNOWN
# 13                    2      TURBO FAN           UNKNOWN
# 14                    4      TURBO FAN           UNKNOWN
# 15                    2     TURBO PROP           UNKNOWN
# 16                    3      TURBO FAN           UNKNOWN
# 17                    2        UNKNOWN           UNKNOWN
# 18                    2        UNKNOWN           UNKNOWN
# 19                    2      TURBO FAN           UNKNOWN
# 20                    2      TURBO FAN           UNKNOWN
# 21                    2      TURBO FAN           UNKNOWN
# 22                    2      TURBO FAN           UNKNOWN
# 23                    3      TURBO FAN           UNKNOWN
# 24                    2      TURBO FAN           UNKNOWN
# 25                    2      TURBO FAN           UNKNOWN
# 26                    2      TURBO JET           UNKNOWN
# 27                    2      TURBO FAN           UNKNOWN
# 28                    2      TURBO FAN           UNKNOWN
# 29                    2      TURBO FAN           UNKNOWN
# 30                    2      TURBO FAN           UNKNOWN
# 31                    3      TURBO FAN           UNKNOWN
# 32                    2      TURBO FAN           UNKNOWN
# 33                    2      TURBO FAN           UNKNOWN
# ...                 ...            ...               ...
# 8975                  1  RECIPROCATING           UNKNOWN
# 9050                  2     TURBO PROP           UNKNOWN
# 9055                  1  RECIPROCATING          PERSONAL
# 9069                  1  RECIPROCATING          PERSONAL
# 9075                  1  RECIPROCATING          PERSONAL
# 9084                  1  RECIPROCATING          PERSONAL
# 9109                  1  RECIPROCATING          PERSONAL
# 9136                  1     TURBO PROP           UNKNOWN
# 9155                  1  RECIPROCATING          PERSONAL
# 9216                  4        UNKNOWN           UNKNOWN
# 9220                  4        UNKNOWN           UNKNOWN
# 9286                  4        UNKNOWN           UNKNOWN
# 9317                  2        UNKNOWN       POSITIONING
# 9592                  4        UNKNOWN           UNKNOWN
# 9616                  1  RECIPROCATING             FERRY
# 9791                  2  RECIPROCATING          PERSONAL
# 10457                 2        UNKNOWN           UNKNOWN
# 11165                 1  RECIPROCATING             FERRY
# 12324                 4        UNKNOWN   PUBLIC AIRCRAFT
# 12337                 1  RECIPROCATING           UNKNOWN
# 12382                 1  RECIPROCATING           UNKNOWN
# 12418                 1  RECIPROCATING          PERSONAL
# 12604                 1  RECIPROCATING          PERSONAL
# 12619                 1  RECIPROCATING           UNKNOWN
# 12663                 1  RECIPROCATING          PERSONAL
# 12723                 1  RECIPROCATING          PERSONAL
# 12804                 1  RECIPROCATING          BUSINESS
# 12871                 1  RECIPROCATING           UNKNOWN
# 12920                 2  RECIPROCATING           UNKNOWN
# 12952                 1  RECIPROCATING           UNKNOWN
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                         0                       0                     0
# 1                         0                       0                     0
# 2                         0                       0                     0
# 3                         0                       0                     0
# 4                         0                       0                     0
# 5                         0                       0                     0
# 8                         0                       0                     0
# 9                         0                       1                     4
# 10                        0                       0                     0
# 13                        0                       0                     0
# 14                        0                       0                     2
# 15                        0                       0                     0
# 16                        0                       0                     0
# 17                        0                       0                     0
# 18                        0                       0                     0
# 19                        0                       0                     0
# 20                        0                       0                     0
# 21                        0                       1                     0
# 22                        3                      50                   137
# 23                        0                       0                     0
# 24                        0                       0                     0
# 25                        0                       0                     0
# 26                        0                       0                     0
# 27                        0                       0                     0
# 28                        0                       1                     3
# 29                        0                       0                     0
# 30                        0                       0                     0
# 31                        0                       1                     9
# 32                        0                       0                     0
# 33                        0                       0                     0
# ...                     ...                     ...                   ...
# 8975                      0                       1                     0
# 9050                      0                       0                     0
# 9055                      0                       1                     0
# 9069                      0                       0                     0
# 9075                      0                       0                     0
# 9084                      0                       1                     0
# 9109                      0                       0                     0
# 9136                      0                       0                     0
# 9155                      0                       1                     0
# 9216                      0                       0                     0
# 9220                      0                       0                     0
# 9286                      0                       0                     1
# 9317                      0                       0                     0
# 9592                      0                       0                     0
# 9616                      0                       0                     1
# 9791                      0                       0                     0
# 10457                     0                       1                     0
# 11165                     0                       0                     0
# 12324                     0                       0                     0
# 12337                     0                       0                     0
# 12382                     0                       0                     1
# 12418                     0                       0                     0
# 12604                     0                       0                     0
# 12619                     0                       0                     0
# 12663                     0                       0                     0
# 12723                     0                       0                     0
# 12804                     0                       0                     0
# 12871                     0                       0                     0
# 12920                     0                       0                     1
# 12952                     0                       0                     0
#
#        Total.Uninjured Weather.Condition Broad.Phase.of.Flight  \
# 0                  588               VMC              STANDING
# 1                  588               VMC                  TAXI
# 2                  501               VMC              STANDING
# 3                  501               VMC                  TAXI
# 4                  454               VMC              STANDING
# 5                  454               VMC                  TAXI
# 8                  393               VMC               TAKEOFF
# 9                  380               VMC                 CLIMB
# 10                 368               VMC                  TAXI
# 13                 352               VMC                  TAXI
# 14                 338               VMC               LANDING
# 15                 339               VMC                  TAXI
# 16                 339               VMC                  TAXI
# 17                 324               VMC              APPROACH
# 18                 324               VMC              APPROACH
# 19                 324               VMC              STANDING
# 20                 324               VMC                  TAXI
# 21                 311               VMC              STANDING
# 22                 117               VMC              APPROACH
# 23                 306               VMC               DESCENT
# 24                 301               VMC              STANDING
# 25                 301               VMC                  TAXI
# 26                 298               VMC                  TAXI
# 27                 298               VMC                  TAXI
# 28                 291               VMC                CRUISE
# 29                 294               VMC              STANDING
# 30                 294               VMC                  TAXI
# 31                 282               VMC               TAKEOFF
# 32                 291               VMC                  TAXI
# 33                 291               VMC              STANDING
# ...                ...               ...                   ...
# 8975                 0               VMC                CRUISE
# 9050                 1               VMC               LANDING
# 9055                 0               VMC               LANDING
# 9069                 1               VMC               LANDING
# 9075                 1               VMC               LANDING
# 9084                 0               VMC                  TAXI
# 9109                 1               VMC               LANDING
# 9136                 1               VMC               DESCENT
# 9155                 0               VMC               LANDING
# 9216                 1               VMC               TAKEOFF
# 9220                 1               VMC               TAKEOFF
# 9286                 0               VMC               LANDING
# 9317                 1               VMC               TAKEOFF
# 9592                 1               VMC               TAKEOFF
# 9616                 0               VMC                CRUISE
# 9791                 1               VMC               LANDING
# 10457                0               VMC              STANDING
# 11165                1               VMC               TAKEOFF
# 12324                1               VMC               LANDING
# 12337                1               VMC               LANDING
# 12382                0               VMC                CRUISE
# 12418                1               VMC              APPROACH
# 12604                1               VMC                CRUISE
# 12619                1               VMC               LANDING
# 12663                1               VMC               LANDING
# 12723                1               VMC               LANDING
# 12804                1               VMC                  TAXI
# 12871                1               VMC               LANDING
# 12920                0               VMC               TAKEOFF
# 12952                1               VMC               LANDING
#
#        Total.Passengers
# 0                   588
# 1                   588
# 2                   501
# 3                   501
# 4                   454
# 5                   454
# 8                   393
# 9                   385
# 10                  368
# 13                  352
# 14                  340
# 15                  339
# 16                  339
# 17                  324
# 18                  324
# 19                  324
# 20                  324
# 21                  312
# 22                  307
# 23                  306
# 24                  301
# 25                  301
# 26                  298
# 27                  298
# 28                  295
# 29                  294
# 30                  294
# 31                  292
# 32                  291
# 33                  291
# ...                 ...
# 8975                  1
# 9050                  1
# 9055                  1
# 9069                  1
# 9075                  1
# 9084                  1
# 9109                  1
# 9136                  1
# 9155                  1
# 9216                  1
# 9220                  1
# 9286                  1
# 9317                  1
# 9592                  1
# 9616                  1
# 9791                  1
# 10457                 1
# 11165                 1
# 12324                 1
# 12337                 1
# 12382                 1
# 12418                 1
# 12604                 1
# 12619                 1
# 12663                 1
# 12723                 1
# 12804                 1
# 12871                 1
# 12920                 1
# 12952                 1
#
# [12954 rows x 15 columns]

# %%
f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.stripplot(x = 'Injury.Severity', y = 'Altitude', data = aviationData)

# %%
f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.stripplot(x = 'Purpose.of.Flight', y = 'Total.Passengers', data = aviationData)

# %%
f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.stripplot(x = 'Aircraft.Damage', y = 'Altitude', data = aviationData)

# %%
f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.stripplot(x = 'Weather.Condition', y = 'Total.Fatal.Injuries', data = aviationData)

# %% [markdown]
# # Predicting Aircraft Damage using Decision tree

# %%
aviationData = pd.read_csv('intermediate.csv')
aviationData.head()
# Out:
#    Unnamed: 0  Altitude   Latitude  Longitude Injury.Severity Aircraft.Damage  \
# 0           0     367.2  39.164723 -96.610412        INCIDENT           MINOR
# 1           1     367.2  39.164723 -96.610412        INCIDENT           MINOR
# 2           2     202.7  41.968611 -87.907778       NON-FATAL     SUBSTANTIAL
# 3           3     202.7  41.968611 -87.907778       NON-FATAL           MINOR
# 4           4     215.4  35.213611 -80.948889       NON-FATAL     SUBSTANTIAL
#
#    Number.of.Engines Engine.Type Purpose.of.Flight  Total.Fatal.Injuries  \
# 0                  3   TURBO FAN           UNKNOWN                     0
# 1                  4   TURBO FAN           UNKNOWN                     0
# 2                  2   TURBO FAN           UNKNOWN                     0
# 3                  2   TURBO FAN           UNKNOWN                     0
# 4                  2   TURBO FAN           UNKNOWN                     0
#
#    Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 0                       0                     0              588
# 1                       0                     0              588
# 2                       0                     0              501
# 3                       0                     0              501
# 4                       0                     0              454
#
#   Weather.Condition Broad.Phase.of.Flight  Total.Passengers
# 0               VMC              STANDING               588
# 1               VMC                  TAXI               588
# 2               VMC              STANDING               501
# 3               VMC                  TAXI               501
# 4               VMC              STANDING               454

# %%
elevationData = pd.Series([])

#Average airplane height in the world is about 10972.8 metres
#Therefore, we subtracted the elevation of ground from sea level ("Altitude"), from the average airplane height
#to get the estimated elevation from ground. 

for i in range(len(aviationData)):
    elevationData[i] = 10972.8 - aviationData['Altitude'][i]
    
aviationData['Elevation.Height'] = elevationData
aviationData.head()
# Out:
#    Unnamed: 0  Altitude   Latitude  Longitude Injury.Severity Aircraft.Damage  \
# 0           0     367.2  39.164723 -96.610412        INCIDENT           MINOR
# 1           1     367.2  39.164723 -96.610412        INCIDENT           MINOR
# 2           2     202.7  41.968611 -87.907778       NON-FATAL     SUBSTANTIAL
# 3           3     202.7  41.968611 -87.907778       NON-FATAL           MINOR
# 4           4     215.4  35.213611 -80.948889       NON-FATAL     SUBSTANTIAL
#
#    Number.of.Engines Engine.Type Purpose.of.Flight  Total.Fatal.Injuries  \
# 0                  3   TURBO FAN           UNKNOWN                     0
# 1                  4   TURBO FAN           UNKNOWN                     0
# 2                  2   TURBO FAN           UNKNOWN                     0
# 3                  2   TURBO FAN           UNKNOWN                     0
# 4                  2   TURBO FAN           UNKNOWN                     0
#
#    Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 0                       0                     0              588
# 1                       0                     0              588
# 2                       0                     0              501
# 3                       0                     0              501
# 4                       0                     0              454
#
#   Weather.Condition Broad.Phase.of.Flight  Total.Passengers  Elevation.Height
# 0               VMC              STANDING               588           10605.6
# 1               VMC                  TAXI               588           10605.6
# 2               VMC              STANDING               501           10770.1
# 3               VMC                  TAXI               501           10770.1
# 4               VMC              STANDING               454           10757.4

# %%
# Extract Response and Predictors
y = pd.DataFrame(aviationData["Aircraft.Damage"])
X = pd.DataFrame(aviationData[["Elevation.Height", "Total.Passengers"]])

# %%
# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (10363, 1) (10363, 2)
# Test Set  : (2591, 1) (2591, 2)

# %%
# Summary Statistics for Predictors
X_train.describe()
# Out:
#        Elevation.Height  Total.Passengers
# count      10363.000000      10363.000000
# mean        8528.225051          6.429991
# std         4300.741335         29.278465
# min        -1561.800000          1.000000
# 25%         9638.500000          1.000000
# 50%        10605.600000          2.000000
# 75%        10780.000000          2.000000
# max        11038.500000        588.000000

# %%
# Draw the distribution of Response
sb.countplot(y_train["Aircraft.Damage"])

# %%
# Relationship between Response and the Predictors
trainDF = pd.concat([y_train, X_train.reindex(index=y_train.index)], sort = False, axis = 1)

f, axes = plt.subplots(2, 1, figsize=(18, 8))

count = 0
for var in X_train:
    sb.stripplot(x = var, y = "Aircraft.Damage", data = trainDF, orient = "h", ax = axes[count])
    count += 1

# %%
from sklearn.tree import DecisionTreeClassifier
# Decision Tree using Train Data
dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
dectree.fit(X_train, y_train)                    # train the decision tree model

# Predict Response corresponding to Predictors
y_train_pred = dectree.predict(X_train)
y_test_pred = dectree.predict(X_test)

# %%
# Plot the Decision Tree
treedot = export_graphviz(dectree,                                      # the model
                          feature_names = X_train.columns,              # the features 
                          out_file = None,                              # output file
                          filled = True,                                # node colors
                          rounded = True,                               # make pretty
                          special_characters = True)                    # postscript

graphviz.Source(treedot)

# %%
# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(X_train, y_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(X_test, y_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(2, 1, figsize=(6, 12))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.8376917880922513
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.8433037437282902

# %% [markdown]
# # Linear Regression to predict Fatal/Serious/Minor injuries

# %%
linreg = LinearRegression()

aviationData = pd.read_csv('intermediate.csv')

# %%
aviationData['Total.Passengers'] = aviationData["Total.Passengers"].astype(float)

elevationData = pd.Series([])

#Average airplane height in the world is about 10972.8 metres
#Therefore, we subtracted the elevation of ground from sea level ("Altitude"), from the average airplane height
#to get the estimated elevation from ground. 

for i in range(len(aviationData)):
    elevationData[i] = 10972.8 - aviationData['Altitude'][i]
    
aviationData['Elevation.Height'] = elevationData

# %%
predictors = pd.DataFrame(aviationData[['Total.Passengers', 'Elevation.Height']])
predictors.head()
# Out:
#    Total.Passengers  Elevation.Height
# 0             588.0           10605.6
# 1             588.0           10605.6
# 2             501.0           10770.1
# 3             501.0           10770.1
# 4             454.0           10757.4

# %%
x = predictors
y = pd.DataFrame(aviationData["Total.Fatal.Injuries"])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 1)
linreg.fit(x_train, y_train)

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

print(pd.DataFrame(list(zip(x_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"]))
print()

y_train_pred = linreg.predict(x_train)
y_test_pred = linreg.predict(x_test)

f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of Total.Fatal.Injuries (Train)")
axes[0].set_ylabel("Predicted values of Total.Fatal.Injuries (Train)")


axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of Total.Fatal.Injuries (Test)")
axes[1].set_ylabel("Predicted values of Total.Fatal.Injuries (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [0.76637388]
# Coefficients of Regression 	: a =  [[ 1.36944353e-02 -5.03236221e-05]]
#
#          Predictors  Coefficients
# 0  Total.Passengers      0.013694
# 1  Elevation.Height     -0.000050
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.015076295041166143
# Mean Squared Error (MSE) 	: 13.989156672633985
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: -0.07976195044368149
# Mean Squared Error (MSE) 	: 1.407339457086422

# %%
x = predictors
y = pd.DataFrame(aviationData["Total.Serious.Injuries"])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 1)

linreg.fit(x_train, y_train)

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

print(pd.DataFrame(list(zip(x_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"]))
print()

y_train_pred = linreg.predict(x_train)
y_test_pred = linreg.predict(x_test)

f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of Total.Serious.Injuries (Train)")
axes[0].set_ylabel("Predicted values of Total.Serious.Injuries (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of Total.Serious.Injuries (Test)")
axes[1].set_ylabel("Predicted values of Total.Serious.Injuries (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [0.21457957]
# Coefficients of Regression 	: a =  [[ 3.49731014e-03 -7.19347109e-06]]
#
#          Predictors  Coefficients
# 0  Total.Passengers      0.003497
# 1  Elevation.Height     -0.000007
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.018493660782133103
# Mean Squared Error (MSE) 	: 0.6407766841636972
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.0030058093355793676
# Mean Squared Error (MSE) 	: 0.3172854293834297

# %%
x = predictors
y = pd.DataFrame(aviationData["Total.Minor.Injuries"])


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 1)

linreg.fit(x_train, y_train)

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

print(pd.DataFrame(list(zip(x_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"]))
print()

y_train_pred = linreg.predict(x_train)
y_test_pred = linreg.predict(x_test)

f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of Total.Minor.Injuries (Train)")
axes[0].set_ylabel("Predicted values of Total.Minor.Injuries (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of Total.Minor.Injuries (Test)")
axes[1].set_ylabel("Predicted values of Total.Minor.Injuries (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [0.27916895]
# Coefficients of Regression 	: a =  [[ 1.10712187e-02 -4.78379595e-06]]
#
#          Predictors  Coefficients
# 0  Total.Passengers      0.011071
# 1  Elevation.Height     -0.000005
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.02902384092115884
# Mean Squared Error (MSE) 	: 3.8106936793222648
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.027177002794243288
# Mean Squared Error (MSE) 	: 1.1101617989667367

# %%
aviationData = pd.read_csv('intermediate.csv')
aviationData
# Out:
#        Unnamed: 0  Altitude   Latitude   Longitude Injury.Severity  \
# 0               0     367.2  39.164723  -96.610412        INCIDENT
# 1               1     367.2  39.164723  -96.610412        INCIDENT
# 2               2     202.7  41.968611  -87.907778       NON-FATAL
# 3               3     202.7  41.968611  -87.907778       NON-FATAL
# 4               4     215.4  35.213611  -80.948889       NON-FATAL
# 5               5     215.4  35.213611  -80.948889       NON-FATAL
# 6               8     367.2  39.164723  -96.610412        INCIDENT
# 7               9     332.8  39.164723  -96.610412       NON-FATAL
# 8              10       2.3  25.793333  -80.290555        INCIDENT
# 9              13     124.0  47.449722 -122.311667       NON-FATAL
# 10             14     367.2  39.164723  -96.610412       NON-FATAL
# 11             15     367.2  39.164723  -96.610412       NON-FATAL
# 12             16     367.2  39.164723  -96.610412       NON-FATAL
# 13             17     519.5  41.983889  -87.663611        INCIDENT
# 14             18     519.5  41.983889  -87.663611        INCIDENT
# 15             19    1635.6  39.861667 -104.673056        INCIDENT
# 16             20    1635.6  39.861667 -104.673056        INCIDENT
# 17             21       3.1  37.618889 -122.374723       NON-FATAL
# 18             22     697.8  37.613333 -122.363889           FATAL
# 19             23     395.2  33.636666  -84.428056        INCIDENT
# 20             24      18.3  38.900000  -77.033334       NON-FATAL
# 21             25      18.3  38.900000  -77.033334       NON-FATAL
# 22             26     304.8  33.636666  -84.428056       NON-FATAL
# 23             27     304.8  33.636666  -84.428056       NON-FATAL
# 24             28   10970.0  21.318611 -157.922500       NON-FATAL
# 25             29       2.3  25.793333  -80.290555       NON-FATAL
# 26             30       2.3  25.793333  -80.290555       NON-FATAL
# 27             31     367.2  39.164723  -96.610412       NON-FATAL
# 28             32       4.7  42.353333  -71.014444       NON-FATAL
# 29             33       4.7  42.353333  -71.014444       NON-FATAL
# ...           ...       ...        ...         ...             ...
# 12924        8975   10932.0  21.715000  -98.608333       NON-FATAL
# 12925        9050    1090.3  45.807778 -108.542777       NON-FATAL
# 12926        9055     307.7  33.423056 -112.685555       NON-FATAL
# 12927        9069     367.2  39.164723  -96.610412       NON-FATAL
# 12928        9075      74.8  48.498611 -122.662500       NON-FATAL
# 12929        9084     367.2  39.164723  -96.610412       NON-FATAL
# 12930        9109     367.2  39.164723  -96.610412       NON-FATAL
# 12931        9136     197.1 -20.889444  -49.388055       NON-FATAL
# 12932        9155     367.2  39.164723  -96.610412       NON-FATAL
# 12933        9216       7.8  24.698055  -77.795555       NON-FATAL
# 12934        9220     367.2  39.164723  -96.610412        INCIDENT
# 12935        9286     367.2  39.164723  -96.610412       NON-FATAL
# 12936        9317       1.3  16.257778  -61.262500       NON-FATAL
# 12937        9592     170.0  51.331389    0.032778       NON-FATAL
# 12938        9616   10967.0  31.252778  130.633056       NON-FATAL
# 12939        9791     160.0  48.751111    2.106389       NON-FATAL
# 12940       10457     367.2  39.164723  -96.610412       NON-FATAL
# 12941       11165     367.2  39.164723  -96.610412       NON-FATAL
# 12942       12324     367.2  39.164723  -96.610412       NON-FATAL
# 12943       12337     367.2  39.164723  -96.610412       NON-FATAL
# 12944       12382   10604.8  39.164723  -96.610412       NON-FATAL
# 12945       12418     332.8  39.164723  -96.610412       NON-FATAL
# 12946       12604   12129.6  39.164723  -96.610412       NON-FATAL
# 12947       12619     367.2  39.164723  -96.610412       NON-FATAL
# 12948       12663     367.2  39.164723  -96.610412       NON-FATAL
# 12949       12723     367.2  39.164723  -96.610412       NON-FATAL
# 12950       12804     367.2  39.164723  -96.610412       NON-FATAL
# 12951       12871     367.2  39.164723  -96.610412       NON-FATAL
# 12952       12920     367.2  39.164723  -96.610412       NON-FATAL
# 12953       12952     367.2  39.164723  -96.610412       NON-FATAL
#
#       Aircraft.Damage  Number.of.Engines    Engine.Type Purpose.of.Flight  \
# 0               MINOR                  3      TURBO FAN           UNKNOWN
# 1               MINOR                  4      TURBO FAN           UNKNOWN
# 2         SUBSTANTIAL                  2      TURBO FAN           UNKNOWN
# 3               MINOR                  2      TURBO FAN           UNKNOWN
# 4         SUBSTANTIAL                  2      TURBO FAN           UNKNOWN
# 5               MINOR                  2      TURBO FAN           UNKNOWN
# 6               MINOR                  3      TURBO FAN           UNKNOWN
# 7         SUBSTANTIAL                  4      TURBO FAN           UNKNOWN
# 8               MINOR                  4      TURBO FAN           UNKNOWN
# 9         SUBSTANTIAL                  2      TURBO FAN           UNKNOWN
# 10        SUBSTANTIAL                  4      TURBO FAN           UNKNOWN
# 11        SUBSTANTIAL                  2     TURBO PROP           UNKNOWN
# 12              MINOR                  3      TURBO FAN           UNKNOWN
# 13        SUBSTANTIAL                  2        UNKNOWN           UNKNOWN
# 14        SUBSTANTIAL                  2        UNKNOWN           UNKNOWN
# 15              MINOR                  2      TURBO FAN           UNKNOWN
# 16              MINOR                  2      TURBO FAN           UNKNOWN
# 17              MINOR                  2      TURBO FAN           UNKNOWN
# 18          DESTROYED                  2      TURBO FAN           UNKNOWN
# 19        SUBSTANTIAL                  3      TURBO FAN           UNKNOWN
# 20        SUBSTANTIAL                  2      TURBO FAN           UNKNOWN
# 21              MINOR                  2      TURBO FAN           UNKNOWN
# 22        SUBSTANTIAL                  2      TURBO JET           UNKNOWN
# 23              MINOR                  2      TURBO FAN           UNKNOWN
# 24          DESTROYED                  2      TURBO FAN           UNKNOWN
# 25        SUBSTANTIAL                  2      TURBO FAN           UNKNOWN
# 26              MINOR                  2      TURBO FAN           UNKNOWN
# 27          DESTROYED                  3      TURBO FAN           UNKNOWN
# 28              MINOR                  2      TURBO FAN           UNKNOWN
# 29        SUBSTANTIAL                  2      TURBO FAN           UNKNOWN
# ...               ...                ...            ...               ...
# 12924       DESTROYED                  1  RECIPROCATING           UNKNOWN
# 12925     SUBSTANTIAL                  2     TURBO PROP           UNKNOWN
# 12926     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12927     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12928     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12929     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12930     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12931     SUBSTANTIAL                  1     TURBO PROP           UNKNOWN
# 12932     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12933     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12934           MINOR                  4        UNKNOWN           UNKNOWN
# 12935     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12936       DESTROYED                  2        UNKNOWN       POSITIONING
# 12937     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12938     SUBSTANTIAL                  1  RECIPROCATING             FERRY
# 12939     SUBSTANTIAL                  2  RECIPROCATING          PERSONAL
# 12940           MINOR                  2        UNKNOWN           UNKNOWN
# 12941     SUBSTANTIAL                  1  RECIPROCATING             FERRY
# 12942     SUBSTANTIAL                  4        UNKNOWN   PUBLIC AIRCRAFT
# 12943     SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
# 12944     SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
# 12945     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12946     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12947     SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
# 12948     SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 12949       DESTROYED                  1  RECIPROCATING          PERSONAL
# 12950     SUBSTANTIAL                  1  RECIPROCATING          BUSINESS
# 12951     SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
# 12952     SUBSTANTIAL                  2  RECIPROCATING           UNKNOWN
# 12953     SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                         0                       0                     0
# 1                         0                       0                     0
# 2                         0                       0                     0
# 3                         0                       0                     0
# 4                         0                       0                     0
# 5                         0                       0                     0
# 6                         0                       0                     0
# 7                         0                       1                     4
# 8                         0                       0                     0
# 9                         0                       0                     0
# 10                        0                       0                     2
# 11                        0                       0                     0
# 12                        0                       0                     0
# 13                        0                       0                     0
# 14                        0                       0                     0
# 15                        0                       0                     0
# 16                        0                       0                     0
# 17                        0                       1                     0
# 18                        3                      50                   137
# 19                        0                       0                     0
# 20                        0                       0                     0
# 21                        0                       0                     0
# 22                        0                       0                     0
# 23                        0                       0                     0
# 24                        0                       1                     3
# 25                        0                       0                     0
# 26                        0                       0                     0
# 27                        0                       1                     9
# 28                        0                       0                     0
# 29                        0                       0                     0
# ...                     ...                     ...                   ...
# 12924                     0                       1                     0
# 12925                     0                       0                     0
# 12926                     0                       1                     0
# 12927                     0                       0                     0
# 12928                     0                       0                     0
# 12929                     0                       1                     0
# 12930                     0                       0                     0
# 12931                     0                       0                     0
# 12932                     0                       1                     0
# 12933                     0                       0                     0
# 12934                     0                       0                     0
# 12935                     0                       0                     1
# 12936                     0                       0                     0
# 12937                     0                       0                     0
# 12938                     0                       0                     1
# 12939                     0                       0                     0
# 12940                     0                       1                     0
# 12941                     0                       0                     0
# 12942                     0                       0                     0
# 12943                     0                       0                     0
# 12944                     0                       0                     1
# 12945                     0                       0                     0
# 12946                     0                       0                     0
# 12947                     0                       0                     0
# 12948                     0                       0                     0
# 12949                     0                       0                     0
# 12950                     0                       0                     0
# 12951                     0                       0                     0
# 12952                     0                       0                     1
# 12953                     0                       0                     0
#
#        Total.Uninjured Weather.Condition Broad.Phase.of.Flight  \
# 0                  588               VMC              STANDING
# 1                  588               VMC                  TAXI
# 2                  501               VMC              STANDING
# 3                  501               VMC                  TAXI
# 4                  454               VMC              STANDING
# 5                  454               VMC                  TAXI
# 6                  393               VMC               TAKEOFF
# 7                  380               VMC                 CLIMB
# 8                  368               VMC                  TAXI
# 9                  352               VMC                  TAXI
# 10                 338               VMC               LANDING
# 11                 339               VMC                  TAXI
# 12                 339               VMC                  TAXI
# 13                 324               VMC              APPROACH
# 14                 324               VMC              APPROACH
# 15                 324               VMC              STANDING
# 16                 324               VMC                  TAXI
# 17                 311               VMC              STANDING
# 18                 117               VMC              APPROACH
# 19                 306               VMC               DESCENT
# 20                 301               VMC              STANDING
# 21                 301               VMC                  TAXI
# 22                 298               VMC                  TAXI
# 23                 298               VMC                  TAXI
# 24                 291               VMC                CRUISE
# 25                 294               VMC              STANDING
# 26                 294               VMC                  TAXI
# 27                 282               VMC               TAKEOFF
# 28                 291               VMC                  TAXI
# 29                 291               VMC              STANDING
# ...                ...               ...                   ...
# 12924                0               VMC                CRUISE
# 12925                1               VMC               LANDING
# 12926                0               VMC               LANDING
# 12927                1               VMC               LANDING
# 12928                1               VMC               LANDING
# 12929                0               VMC                  TAXI
# 12930                1               VMC               LANDING
# 12931                1               VMC               DESCENT
# 12932                0               VMC               LANDING
# 12933                1               VMC               TAKEOFF
# 12934                1               VMC               TAKEOFF
# 12935                0               VMC               LANDING
# 12936                1               VMC               TAKEOFF
# 12937                1               VMC               TAKEOFF
# 12938                0               VMC                CRUISE
# 12939                1               VMC               LANDING
# 12940                0               VMC              STANDING
# 12941                1               VMC               TAKEOFF
# 12942                1               VMC               LANDING
# 12943                1               VMC               LANDING
# 12944                0               VMC                CRUISE
# 12945                1               VMC              APPROACH
# 12946                1               VMC                CRUISE
# 12947                1               VMC               LANDING
# 12948                1               VMC               LANDING
# 12949                1               VMC               LANDING
# 12950                1               VMC                  TAXI
# 12951                1               VMC               LANDING
# 12952                0               VMC               TAKEOFF
# 12953                1               VMC               LANDING
#
#        Total.Passengers
# 0                   588
# 1                   588
# 2                   501
# 3                   501
# 4                   454
# 5                   454
# 6                   393
# 7                   385
# 8                   368
# 9                   352
# 10                  340
# 11                  339
# 12                  339
# 13                  324
# 14                  324
# 15                  324
# 16                  324
# 17                  312
# 18                  307
# 19                  306
# 20                  301
# 21                  301
# 22                  298
# 23                  298
# 24                  295
# 25                  294
# 26                  294
# 27                  292
# 28                  291
# 29                  291
# ...                 ...
# 12924                 1
# 12925                 1
# 12926                 1
# 12927                 1
# 12928                 1
# 12929                 1
# 12930                 1
# 12931                 1
# 12932                 1
# 12933                 1
# 12934                 1
# 12935                 1
# 12936                 1
# 12937                 1
# 12938                 1
# 12939                 1
# 12940                 1
# 12941                 1
# 12942                 1
# 12943                 1
# 12944                 1
# 12945                 1
# 12946                 1
# 12947                 1
# 12948                 1
# 12949                 1
# 12950                 1
# 12951                 1
# 12952                 1
# 12953                 1
#
# [12954 rows x 16 columns]

# %%
maneuvering = pd.DataFrame(aviationData[aviationData["Broad.Phase.of.Flight"] == 'MANEUVERING'])
maneuvering
# Out:
#        Unnamed: 0  Altitude   Latitude   Longitude Injury.Severity  \
# 359           443   10604.8  55.425556 -131.505000           FATAL
# 360           444   10604.8  55.425556 -131.505000           FATAL
# 368           453   12194.7  45.950000 -112.483333           FATAL
# 374           459   10604.8   9.865278  -85.366111           FATAL
# 400           492   12496.8  46.587222 -121.352222           FATAL
# 401           493   10568.6  39.164723  -96.610412           FATAL
# 431           533   10961.6  55.700000 -131.633333           FATAL
# 433           536   12129.6  39.164723  -96.610412           FATAL
# 464           571   10604.8  39.164723  -96.610412           FATAL
# 493           606   12129.6  39.164723  -96.610412       NON-FATAL
# 512           631   10945.6  15.062222  145.623611           FATAL
# 586           711   12274.9  38.343333  -82.556111           FATAL
# 594           719   12129.6  39.164723  -96.610412           FATAL
# 704           846   12454.1  40.189444  -74.119167           FATAL
# 705           847   12295.8  36.130556  -96.080278           FATAL
# 706           848   11063.3  38.929167 -119.818334           FATAL
# 712           854    8841.1  33.459167 -105.453333           FATAL
# 714           856   11174.0  34.880278 -112.253333           FATAL
# 717           859   12129.6  39.164723  -96.610412           FATAL
# 719           861   12129.6  39.164723  -96.610412           FATAL
# 728           870   12382.9  62.181667 -150.506667           FATAL
# 729           871   12382.9  62.181667 -150.506667           FATAL
# 732           874   12129.6  39.164723  -96.610412           FATAL
# 738           883   12136.0  38.272223  -78.890000           FATAL
# 767           920   12229.7  38.838055  -92.002500       NON-FATAL
# 818           973   10523.7  39.521945 -111.408333       NON-FATAL
# 821           978   12334.3  32.573889  -85.652778       NON-FATAL
# 878          1036   10604.8  39.164723  -96.610412       NON-FATAL
# 897          1055   10604.8  39.164723  -96.610412       NON-FATAL
# 926          1086   10829.7  61.036944 -149.045277           FATAL
# ...           ...       ...        ...         ...             ...
# 12725        3507   11932.5  33.162500 -116.959722           FATAL
# 12741        3845    9456.9  24.170556  104.900556           FATAL
# 12743        3851    9061.8  29.097777 -107.480000           FATAL
# 12750        3877   10451.0  65.863611  -18.936389           FATAL
# 12753        3944   12115.2  42.806944  -98.189444           FATAL
# 12758        4065    9742.7  42.650000 -122.325000       NON-FATAL
# 12822        7560   12172.7  39.932778  -83.461944           FATAL
# 12834        7592   10604.8  39.164723  -96.610412           FATAL
# 12836        7597   10847.0 -18.888611  -40.192222           FATAL
# 12839        7606   10252.0 -43.185555  146.366667           FATAL
# 12842        7629   10604.8  39.164723  -96.610412           FATAL
# 12846        7637   10972.0  39.925834    2.983056           FATAL
# 12848        7639   10604.8  39.164723  -96.610412           FATAL
# 12849        7640   10604.8  39.164723  -96.610412           FATAL
# 12851        7655   10836.0  19.033334  -70.429445           FATAL
# 12854        7666   10489.7 -21.622778  -48.867778           FATAL
# 12855        7674   10744.0  18.673056  103.885000           FATAL
# 12857        7682   10604.8  39.164723  -96.610412           FATAL
# 12862        7715   10212.8 -14.910556  -54.215556           FATAL
# 12865        7731    9955.0   4.651944  -75.913056           FATAL
# 12866        7740   10790.0   4.091111  -72.955833           FATAL
# 12867        7748   10531.0  49.282223   13.888333           FATAL
# 12871        7803   10329.3  -5.662222  -41.045833           FATAL
# 12895        8462   10966.0  -1.675000  -79.654167       NON-FATAL
# 12898        8510   10951.3  10.751389  -74.154722       NON-FATAL
# 12903        8559   10907.0   7.901111    8.322778       NON-FATAL
# 12907        8607   12369.8  44.357778 -122.917778       NON-FATAL
# 12909        8615    9956.2  48.980278 -118.017778       NON-FATAL
# 12911        8662   10936.0  22.451944  114.226667       NON-FATAL
# 12923        8964   10972.0  43.600000    4.066667       NON-FATAL
#
#       Aircraft.Damage  Number.of.Engines    Engine.Type Purpose.of.Flight  \
# 359       SUBSTANTIAL                  1     TURBO PROP           UNKNOWN
# 360         DESTROYED                  1  RECIPROCATING           UNKNOWN
# 368       SUBSTANTIAL                  1     TURBO PROP          PERSONAL
# 374         DESTROYED                  1     TURBO PROP           UNKNOWN
# 400         DESTROYED                  1     TURBO PROP          PERSONAL
# 401         DESTROYED                  2     TURBO PROP           UNKNOWN
# 431         DESTROYED                  1  RECIPROCATING           UNKNOWN
# 433         DESTROYED                  1  RECIPROCATING          PERSONAL
# 464         DESTROYED                  1  RECIPROCATING           UNKNOWN
# 493       SUBSTANTIAL                  2      TURBO JET          PERSONAL
# 512         DESTROYED                  1  RECIPROCATING           UNKNOWN
# 586         DESTROYED                  2  RECIPROCATING          PERSONAL
# 594         DESTROYED                  1  RECIPROCATING          PERSONAL
# 704       SUBSTANTIAL                  2  RECIPROCATING          PERSONAL
# 705         DESTROYED                  1  RECIPROCATING          PERSONAL
# 706       SUBSTANTIAL                  2  RECIPROCATING          PERSONAL
# 712         DESTROYED                  2     TURBO PROP           UNKNOWN
# 714         DESTROYED                  2     TURBO PROP          PERSONAL
# 717         DESTROYED                  1  RECIPROCATING          PERSONAL
# 719         DESTROYED                  2  RECIPROCATING          PERSONAL
# 728         DESTROYED                  1  RECIPROCATING          PERSONAL
# 729             MINOR                  1  RECIPROCATING          PERSONAL
# 732       SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 738       SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 767       SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 818       SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 821       SUBSTANTIAL                  1  RECIPROCATING          PERSONAL
# 878       SUBSTANTIAL                  2     TURBO PROP          BUSINESS
# 897       SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
# 926         DESTROYED                  1  RECIPROCATING          PERSONAL
# ...               ...                ...            ...               ...
# 12725       DESTROYED                  1  RECIPROCATING          PERSONAL
# 12741     SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
# 12743     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12750     SUBSTANTIAL                  1  RECIPROCATING             FERRY
# 12753       DESTROYED                  2  RECIPROCATING          PERSONAL
# 12758     SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
# 12822       DESTROYED                  1  RECIPROCATING          PERSONAL
# 12834     SUBSTANTIAL                  4        UNKNOWN    OTHER WORK USE
# 12836     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12839       DESTROYED                  4  RECIPROCATING           UNKNOWN
# 12842       DESTROYED                  1     TURBO PROP           UNKNOWN
# 12846     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12848     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12849       DESTROYED                  4        UNKNOWN           UNKNOWN
# 12851     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12854       DESTROYED                  4        UNKNOWN           UNKNOWN
# 12855     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12857     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12862       DESTROYED                  1     TURBO PROP           UNKNOWN
# 12865       DESTROYED                  1  RECIPROCATING           UNKNOWN
# 12866       DESTROYED                  1  RECIPROCATING           UNKNOWN
# 12867     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12871       DESTROYED                  4        UNKNOWN           UNKNOWN
# 12895       DESTROYED                  4     TURBO PROP           UNKNOWN
# 12898           MINOR                  4        UNKNOWN           UNKNOWN
# 12903     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12907     SUBSTANTIAL                  4        UNKNOWN          PERSONAL
# 12909     SUBSTANTIAL                  1     TURBO PROP   PUBLIC AIRCRAFT
# 12911     SUBSTANTIAL                  4        UNKNOWN           UNKNOWN
# 12923     SUBSTANTIAL                  1  RECIPROCATING           UNKNOWN
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 359                       6                       9                     1
# 360                       6                       9                     1
# 368                      14                       0                     0
# 374                      12                       0                     0
# 400                      10                       0                     0
# 401                      10                       0                     0
# 431                       5                       4                     0
# 433                       3                       2                     4
# 464                       8                       0                     0
# 493                       0                       0                     0
# 512                       3                       4                     0
# 586                       6                       0                     0
# 594                       6                       0                     0
# 704                       5                       0                     0
# 705                       5                       0                     0
# 706                       5                       0                     0
# 712                       5                       0                     0
# 714                       5                       0                     0
# 717                       5                       0                     0
# 719                       5                       0                     0
# 728                       4                       0                     0
# 729                       4                       0                     0
# 732                       4                       1                     0
# 738                       2                       0                     0
# 767                       0                       0                     2
# 818                       0                       2                     3
# 821                       0                       0                     2
# 878                       0                       0                     1
# 897                       0                       0                     4
# 926                       4                       0                     0
# ...                     ...                     ...                   ...
# 12725                     2                       0                     0
# 12741                     1                       0                     0
# 12743                     1                       1                     0
# 12750                     1                       1                     0
# 12753                     1                       1                     0
# 12758                     0                       0                     0
# 12822                     1                       0                     0
# 12834                     1                       0                     0
# 12836                     1                       0                     0
# 12839                     1                       0                     0
# 12842                     1                       0                     0
# 12846                     1                       0                     0
# 12848                     1                       0                     0
# 12849                     1                       0                     0
# 12851                     1                       0                     0
# 12854                     1                       0                     0
# 12855                     1                       0                     0
# 12857                     1                       0                     0
# 12862                     1                       0                     0
# 12865                     1                       0                     0
# 12866                     1                       0                     0
# 12867                     1                       0                     0
# 12871                     1                       0                     0
# 12895                     0                       1                     0
# 12898                     0                       0                     0
# 12903                     0                       0                     1
# 12907                     0                       1                     0
# 12909                     0                       1                     0
# 12911                     0                       1                     0
# 12923                     0                       0                     0
#
#        Total.Uninjured Weather.Condition Broad.Phase.of.Flight  \
# 359                  0               VMC           MANEUVERING
# 360                  0               VMC           MANEUVERING
# 368                  0               VMC           MANEUVERING
# 374                  0               VMC           MANEUVERING
# 400                  0               IMC           MANEUVERING
# 401                  0               VMC           MANEUVERING
# 431                  0               VMC           MANEUVERING
# 433                  0               VMC           MANEUVERING
# 464                  0               VMC           MANEUVERING
# 493                  8               VMC           MANEUVERING
# 512                  0               VMC           MANEUVERING
# 586                  0               IMC           MANEUVERING
# 594                  0               IMC           MANEUVERING
# 704                  0               VMC           MANEUVERING
# 705                  0               IMC           MANEUVERING
# 706                  0               VMC           MANEUVERING
# 712                  0               VMC           MANEUVERING
# 714                  0               VMC           MANEUVERING
# 717                  0               VMC           MANEUVERING
# 719                  0               VMC           MANEUVERING
# 728                  1               VMC           MANEUVERING
# 729                  1               VMC           MANEUVERING
# 732                  0               VMC           MANEUVERING
# 738                  3               VMC           MANEUVERING
# 767                  3               VMC           MANEUVERING
# 818                  0               VMC           MANEUVERING
# 821                  3               VMC           MANEUVERING
# 878                  4               VMC           MANEUVERING
# 897                  1               VMC           MANEUVERING
# 926                  0               VMC           MANEUVERING
# ...                ...               ...                   ...
# 12725                0               VMC           MANEUVERING
# 12741                1               VMC           MANEUVERING
# 12743                0               VMC           MANEUVERING
# 12750                0               VMC           MANEUVERING
# 12753                0               VMC           MANEUVERING
# 12758                2               VMC           MANEUVERING
# 12822                0               VMC           MANEUVERING
# 12834                0               VMC           MANEUVERING
# 12836                0               VMC           MANEUVERING
# 12839                0               VMC           MANEUVERING
# 12842                0               VMC           MANEUVERING
# 12846                0               VMC           MANEUVERING
# 12848                0               VMC           MANEUVERING
# 12849                0               VMC           MANEUVERING
# 12851                0               VMC           MANEUVERING
# 12854                0               VMC           MANEUVERING
# 12855                0               VMC           MANEUVERING
# 12857                0               VMC           MANEUVERING
# 12862                0               VMC           MANEUVERING
# 12865                0               VMC           MANEUVERING
# 12866                0               VMC           MANEUVERING
# 12867                0               VMC           MANEUVERING
# 12871                0               VMC           MANEUVERING
# 12895                0               VMC           MANEUVERING
# 12898                1               VMC           MANEUVERING
# 12903                0               VMC           MANEUVERING
# 12907                0               VMC           MANEUVERING
# 12909                0               VMC           MANEUVERING
# 12911                0               VMC           MANEUVERING
# 12923                1               VMC           MANEUVERING
#
#        Total.Passengers
# 359                  16
# 360                  16
# 368                  14
# 374                  12
# 400                  10
# 401                  10
# 431                   9
# 433                   9
# 464                   8
# 493                   8
# 512                   7
# 586                   6
# 594                   6
# 704                   5
# 705                   5
# 706                   5
# 712                   5
# 714                   5
# 717                   5
# 719                   5
# 728                   5
# 729                   5
# 732                   5
# 738                   5
# 767                   5
# 818                   5
# 821                   5
# 878                   5
# 897                   5
# 926                   4
# ...                 ...
# 12725                 2
# 12741                 2
# 12743                 2
# 12750                 2
# 12753                 2
# 12758                 2
# 12822                 1
# 12834                 1
# 12836                 1
# 12839                 1
# 12842                 1
# 12846                 1
# 12848                 1
# 12849                 1
# 12851                 1
# 12854                 1
# 12855                 1
# 12857                 1
# 12862                 1
# 12865                 1
# 12866                 1
# 12867                 1
# 12871                 1
# 12895                 1
# 12898                 1
# 12903                 1
# 12907                 1
# 12909                 1
# 12911                 1
# 12923                 1
#
# [859 rows x 16 columns]

# %%
maneuvering['Injury.Severity'].value_counts()
# Out:
# FATAL        487
# NON-FATAL    365
# INCIDENT       7
# Name: Injury.Severity, dtype: int64

# %%
maneuvering['Aircraft.Damage'].value_counts()
# Out:
# SUBSTANTIAL    568
# DESTROYED      281
# MINOR           10
# Name: Aircraft.Damage, dtype: int64

# %%
f, axes = plt.subplots(1, 1, figsize=(16, 8))
sb.countplot(x = 'Total.Passengers', hue = 'Injury.Severity', data = maneuvering)

# %%
more = pd.DataFrame(aviationData[aviationData['Total.Passengers'] > 15])
less = pd.DataFrame(aviationData[aviationData['Total.Passengers'] < 15])
more
# Out:
#        Unnamed: 0  Altitude   Latitude   Longitude Injury.Severity  \
# 0               0     367.2  39.164723  -96.610412        INCIDENT
# 1               1     367.2  39.164723  -96.610412        INCIDENT
# 2               2     202.7  41.968611  -87.907778       NON-FATAL
# 3               3     202.7  41.968611  -87.907778       NON-FATAL
# 4               4     215.4  35.213611  -80.948889       NON-FATAL
# 5               5     215.4  35.213611  -80.948889       NON-FATAL
# 6               8     367.2  39.164723  -96.610412        INCIDENT
# 7               9     332.8  39.164723  -96.610412       NON-FATAL
# 8              10       2.3  25.793333  -80.290555        INCIDENT
# 9              13     124.0  47.449722 -122.311667       NON-FATAL
# 10             14     367.2  39.164723  -96.610412       NON-FATAL
# 11             15     367.2  39.164723  -96.610412       NON-FATAL
# 12             16     367.2  39.164723  -96.610412       NON-FATAL
# 13             17     519.5  41.983889  -87.663611        INCIDENT
# 14             18     519.5  41.983889  -87.663611        INCIDENT
# 15             19    1635.6  39.861667 -104.673056        INCIDENT
# 16             20    1635.6  39.861667 -104.673056        INCIDENT
# 17             21       3.1  37.618889 -122.374723       NON-FATAL
# 18             22     697.8  37.613333 -122.363889           FATAL
# 19             23     395.2  33.636666  -84.428056        INCIDENT
# 20             24      18.3  38.900000  -77.033334       NON-FATAL
# 21             25      18.3  38.900000  -77.033334       NON-FATAL
# 22             26     304.8  33.636666  -84.428056       NON-FATAL
# 23             27     304.8  33.636666  -84.428056       NON-FATAL
# 24             28   10970.0  21.318611 -157.922500       NON-FATAL
# 25             29       2.3  25.793333  -80.290555       NON-FATAL
# 26             30       2.3  25.793333  -80.290555       NON-FATAL
# 27             31     367.2  39.164723  -96.610412       NON-FATAL
# 28             32       4.7  42.353333  -71.014444       NON-FATAL
# 29             33       4.7  42.353333  -71.014444       NON-FATAL
# ...           ...       ...        ...         ...             ...
# 12483         228     202.7  39.164723  -96.610412        INCIDENT
# 12484         236     581.1  39.164723  -96.610412        INCIDENT
# 12485         238     367.2  47.447222 -122.314167        INCIDENT
# 12486         241     367.2  39.164723  -96.610412        INCIDENT
# 12487         243     367.2  39.164723  -96.610412        INCIDENT
# 12488         249     359.3  39.164723  -96.610412           FATAL
# 12489         250     483.1  39.164723  -96.610412       NON-FATAL
# 12490         254     695.8  39.164723  -96.610412        INCIDENT
# 12491         261       2.0  38.750278  -90.375556        INCIDENT
# 12492         262     367.2  39.164723  -96.610412        INCIDENT
# 12493         264     367.2  39.164723  -96.610412       NON-FATAL
# 12494         268     367.2 -37.933056  -57.581945        INCIDENT
# 12495         269    2493.3  39.164723  -96.610412       NON-FATAL
# 12496         270     367.2  39.164723  -96.610412        INCIDENT
# 12497         282       7.2  42.357778  -71.006389        INCIDENT
# 12498         296     258.1  39.164723  -96.610412           FATAL
# 12499         311     341.5  39.164723  -96.610412           FATAL
# 12500         320   10604.8  38.948611  -77.450278        INCIDENT
# 12501         322   10604.8  39.164723  -96.610412           FATAL
# 12502         324     367.2  39.164723  -96.610412       NON-FATAL
# 12503         325     367.2  41.990277  -87.904722        INCIDENT
# 12504         363    1286.6  39.177500  -76.668889        INCIDENT
# 12505         377      33.7  39.164723  -96.610412        INCIDENT
# 12506         393      51.6  41.973334  -87.899166       NON-FATAL
# 12507         399     184.1  26.558611  -78.695555       NON-FATAL
# 12508         406     355.8  38.748611  -90.370000       NON-FATAL
# 12509         412     367.2  39.164723  -96.610412       NON-FATAL
# 12510         424     304.8  39.164723  -96.610412        INCIDENT
# 12511         437     663.3   8.823611  -75.825834        INCIDENT
# 12512         445     367.2  39.164723  -96.610412        INCIDENT
#
#       Aircraft.Damage  Number.of.Engines Engine.Type Purpose.of.Flight  \
# 0               MINOR                  3   TURBO FAN           UNKNOWN
# 1               MINOR                  4   TURBO FAN           UNKNOWN
# 2         SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 3               MINOR                  2   TURBO FAN           UNKNOWN
# 4         SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 5               MINOR                  2   TURBO FAN           UNKNOWN
# 6               MINOR                  3   TURBO FAN           UNKNOWN
# 7         SUBSTANTIAL                  4   TURBO FAN           UNKNOWN
# 8               MINOR                  4   TURBO FAN           UNKNOWN
# 9         SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 10        SUBSTANTIAL                  4   TURBO FAN           UNKNOWN
# 11        SUBSTANTIAL                  2  TURBO PROP           UNKNOWN
# 12              MINOR                  3   TURBO FAN           UNKNOWN
# 13        SUBSTANTIAL                  2     UNKNOWN           UNKNOWN
# 14        SUBSTANTIAL                  2     UNKNOWN           UNKNOWN
# 15              MINOR                  2   TURBO FAN           UNKNOWN
# 16              MINOR                  2   TURBO FAN           UNKNOWN
# 17              MINOR                  2   TURBO FAN           UNKNOWN
# 18          DESTROYED                  2   TURBO FAN           UNKNOWN
# 19        SUBSTANTIAL                  3   TURBO FAN           UNKNOWN
# 20        SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 21              MINOR                  2   TURBO FAN           UNKNOWN
# 22        SUBSTANTIAL                  2   TURBO JET           UNKNOWN
# 23              MINOR                  2   TURBO FAN           UNKNOWN
# 24          DESTROYED                  2   TURBO FAN           UNKNOWN
# 25        SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 26              MINOR                  2   TURBO FAN           UNKNOWN
# 27          DESTROYED                  3   TURBO FAN           UNKNOWN
# 28              MINOR                  2   TURBO FAN           UNKNOWN
# 29        SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# ...               ...                ...         ...               ...
# 12483           MINOR                  4     UNKNOWN           UNKNOWN
# 12484     SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 12485     SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 12486           MINOR                  4     UNKNOWN           UNKNOWN
# 12487       DESTROYED                  2   TURBO FAN           UNKNOWN
# 12488       DESTROYED                  4   TURBO FAN           UNKNOWN
# 12489     SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 12490           MINOR                  2   TURBO FAN           UNKNOWN
# 12491           MINOR                  2   TURBO FAN           UNKNOWN
# 12492     SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 12493       DESTROYED                  4   TURBO FAN           UNKNOWN
# 12494           MINOR                  4     UNKNOWN           UNKNOWN
# 12495     SUBSTANTIAL                  4   TURBO FAN           UNKNOWN
# 12496           MINOR                  2     UNKNOWN           UNKNOWN
# 12497     SUBSTANTIAL                  4   TURBO FAN           UNKNOWN
# 12498       DESTROYED                  4     UNKNOWN           UNKNOWN
# 12499       DESTROYED                  4     UNKNOWN           UNKNOWN
# 12500           MINOR                  2   TURBO FAN           UNKNOWN
# 12501       DESTROYED                  2   TURBO FAN           UNKNOWN
# 12502     SUBSTANTIAL                  2  TURBO PROP           UNKNOWN
# 12503           MINOR                  2   TURBO FAN           UNKNOWN
# 12504     SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 12505           MINOR                  2  TURBO PROP           UNKNOWN
# 12506     SUBSTANTIAL                  2   TURBO FAN           UNKNOWN
# 12507     SUBSTANTIAL                  4     UNKNOWN           UNKNOWN
# 12508     SUBSTANTIAL                  4     UNKNOWN           UNKNOWN
# 12509     SUBSTANTIAL                  4   TURBO FAN           UNKNOWN
# 12510           MINOR                  4     UNKNOWN           UNKNOWN
# 12511     SUBSTANTIAL                  2  TURBO PROP           UNKNOWN
# 12512     SUBSTANTIAL                  4     UNKNOWN           UNKNOWN
#
#        Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                         0                       0                     0
# 1                         0                       0                     0
# 2                         0                       0                     0
# 3                         0                       0                     0
# 4                         0                       0                     0
# 5                         0                       0                     0
# 6                         0                       0                     0
# 7                         0                       1                     4
# 8                         0                       0                     0
# 9                         0                       0                     0
# 10                        0                       0                     2
# 11                        0                       0                     0
# 12                        0                       0                     0
# 13                        0                       0                     0
# 14                        0                       0                     0
# 15                        0                       0                     0
# 16                        0                       0                     0
# 17                        0                       1                     0
# 18                        3                      50                   137
# 19                        0                       0                     0
# 20                        0                       0                     0
# 21                        0                       0                     0
# 22                        0                       0                     0
# 23                        0                       0                     0
# 24                        0                       1                     3
# 25                        0                       0                     0
# 26                        0                       0                     0
# 27                        0                       1                     9
# 28                        0                       0                     0
# 29                        0                       0                     0
# ...                     ...                     ...                   ...
# 12483                     0                       0                     0
# 12484                     0                       0                     0
# 12485                     0                       0                     0
# 12486                     0                       0                     0
# 12487                     0                       0                     0
# 12488                   112                       1                     0
# 12489                     0                       1                     0
# 12490                     0                       0                     0
# 12491                     0                       0                     0
# 12492                     0                       0                     0
# 12493                     0                      16                    26
# 12494                     0                       0                     0
# 12495                     0                       1                    21
# 12496                     0                       0                     0
# 12497                     0                       0                     0
# 12498                    41                       0                     0
# 12499                    71                       0                     0
# 12500                     0                       0                     0
# 12501                    65                       0                     0
# 12502                     0                       0                     0
# 12503                     0                       0                     0
# 12504                     0                       0                     0
# 12505                     0                       0                     0
# 12506                     0                       0                     1
# 12507                     0                       0                     0
# 12508                     0                       0                     0
# 12509                     0                       0                     3
# 12510                     0                       0                     0
# 12511                     0                       0                     0
# 12512                     0                       0                     0
#
#        Total.Uninjured Weather.Condition Broad.Phase.of.Flight  \
# 0                  588               VMC              STANDING
# 1                  588               VMC                  TAXI
# 2                  501               VMC              STANDING
# 3                  501               VMC                  TAXI
# 4                  454               VMC              STANDING
# 5                  454               VMC                  TAXI
# 6                  393               VMC               TAKEOFF
# 7                  380               VMC                 CLIMB
# 8                  368               VMC                  TAXI
# 9                  352               VMC                  TAXI
# 10                 338               VMC               LANDING
# 11                 339               VMC                  TAXI
# 12                 339               VMC                  TAXI
# 13                 324               VMC              APPROACH
# 14                 324               VMC              APPROACH
# 15                 324               VMC              STANDING
# 16                 324               VMC                  TAXI
# 17                 311               VMC              STANDING
# 18                 117               VMC              APPROACH
# 19                 306               VMC               DESCENT
# 20                 301               VMC              STANDING
# 21                 301               VMC                  TAXI
# 22                 298               VMC                  TAXI
# 23                 298               VMC                  TAXI
# 24                 291               VMC                CRUISE
# 25                 294               VMC              STANDING
# 26                 294               VMC                  TAXI
# 27                 282               VMC               TAKEOFF
# 28                 291               VMC                  TAXI
# 29                 291               VMC              STANDING
# ...                ...               ...                   ...
# 12483              127               VMC               LANDING
# 12484              122               VMC                 CLIMB
# 12485              120               VMC               TAKEOFF
# 12486              118               VMC               LANDING
# 12487              117               VMC               LANDING
# 12488                0               VMC               TAKEOFF
# 12489              112               VMC               DESCENT
# 12490              111               VMC                 CLIMB
# 12491              107               VMC               TAKEOFF
# 12492              104               VMC               TAKEOFF
# 12493               60               VMC               TAKEOFF
# 12494              101               VMC                  TAXI
# 12495               79               VMC                  TAXI
# 12496              101               VMC               LANDING
# 12497               89               VMC               TAKEOFF
# 12498               39               VMC               TAKEOFF
# 12499                0               VMC               TAKEOFF
# 12500               67               VMC                CRUISE
# 12501                0               VMC                CRUISE
# 12502               64               VMC               LANDING
# 12503               64               VMC               TAKEOFF
# 12504               51               VMC                 CLIMB
# 12505               48               VMC               TAKEOFF
# 12506               37               VMC                  TAXI
# 12507               36               VMC               LANDING
# 12508               33               VMC              APPROACH
# 12509               28               VMC               LANDING
# 12510               23               VMC               LANDING
# 12511               18               VMC                 CLIMB
# 12512               16               VMC               TAKEOFF
#
#        Total.Passengers
# 0                   588
# 1                   588
# 2                   501
# 3                   501
# 4                   454
# 5                   454
# 6                   393
# 7                   385
# 8                   368
# 9                   352
# 10                  340
# 11                  339
# 12                  339
# 13                  324
# 14                  324
# 15                  324
# 16                  324
# 17                  312
# 18                  307
# 19                  306
# 20                  301
# 21                  301
# 22                  298
# 23                  298
# 24                  295
# 25                  294
# 26                  294
# 27                  292
# 28                  291
# 29                  291
# ...                 ...
# 12483               127
# 12484               122
# 12485               120
# 12486               118
# 12487               117
# 12488               113
# 12489               113
# 12490               111
# 12491               107
# 12492               104
# 12493               102
# 12494               101
# 12495               101
# 12496               101
# 12497                89
# 12498                80
# 12499                71
# 12500                67
# 12501                65
# 12502                64
# 12503                64
# 12504                51
# 12505                48
# 12506                38
# 12507                36
# 12508                33
# 12509                31
# 12510                23
# 12511                18
# 12512                16
#
# [442 rows x 16 columns]

# %%
more['Injury.Severity'].value_counts()
print("NONFATAL: ", 245/442 * 100)
print("INCIDENT: ", 180/442 * 100)
print("FATAL: ", 17/442 * 100)
# Out:
# NONFATAL:  55.42986425339367
# INCIDENT:  40.723981900452486
# FATAL:  3.8461538461538463

# %%
aviationData['Injury.Severity'].value_counts()
print("NONFATAL: ", 10341/12954 * 100)
print("FATAL: ", 2177/12954 * 100)
print("INCIDENT: ", 436/12954 * 100)
# Out:
# NONFATAL:  79.82862436313108
# FATAL:  16.805619885749575
# INCIDENT:  3.3657557511193454

# %%
less['Injury.Severity'].value_counts()
print("NONFATAL: ", 10093/12507 * 100)
print("FATAL: ", 2159/12507 * 100)
print("INCIDENT: ", 255/12507 * 100)
# Out:
# NONFATAL:  80.6988086671464
# FATAL:  17.262333093467657
# INCIDENT:  2.0388582393859442
