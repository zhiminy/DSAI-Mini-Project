# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
url = 'https://raw.githubusercontent.com/zzzhimin/DSAI-Mini-Project/master/AviationData.csv'
data = pd.read_csv(url,encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#          Event.Id Investigation.Type  ... Report.Status Publication.Date
# 0  20200102X82407           Accident  ...       Factual       13/01/2020
# 1  20191231X83852           Accident  ...   Preliminary       08/01/2020
# 2  20200102X54844           Accident  ...   Preliminary       02/01/2020
# 3  20191230X91852           Accident  ...   Preliminary       31/12/2019
# 4  20191228X62945                NaN  ...   Preliminary       03/01/2020
#
# [5 rows x 31 columns]

# %%
# Data cleaning
# Remove the amateur built airplanes
data2 = data[data['Amateur.Built'] != 'Yes']
data2.head()
# Out:
#          Event.Id Investigation.Type  ... Report.Status Publication.Date
# 0  20200102X82407           Accident  ...       Factual       13/01/2020
# 1  20191231X83852           Accident  ...   Preliminary       08/01/2020
# 2  20200102X54844           Accident  ...   Preliminary       02/01/2020
# 4  20191228X62945                NaN  ...   Preliminary       03/01/2020
# 5  20191228X23853           Accident  ...   Preliminary       06/01/2020
#
# [5 rows x 31 columns]
